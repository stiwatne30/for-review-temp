# %%
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.2f' % x)
import numpy as np
from google.cloud import bigquery
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style('darkgrid')
import joblib
import warnings
warnings.filterwarnings('ignore') 
import re

bq_client = bigquery.Client()

# %%
import google.auth
from google.cloud import bigquery
from google.cloud import bigquery_storage
import time

bqclient = bigquery.Client()
bqstorageclient = bigquery_storage.BigQueryReadClient()

# %%
def pvs_eda(input_df, cat_col_name, drop_cols=False):
    
    # pivot
    df_cat = pd.pivot_table(
        input_df, 
        values='GA_pageViews',
        columns= cat_col_name,
        index='subscription_status',
        aggfunc='sum')\
        .reset_index()
    
    # drop none and other cols
    if drop_cols==True:
        
        if 'none' in list(df_cat.columns):
            df_cat.drop('none', axis=1, inplace=True)
        
        if 'other' in list(df_cat.columns):
            df_cat.drop('other', axis=1, inplace=True)

    
    # percentage calc below
    df_cat = df_cat.fillna(0)
    df_cat = df_cat.T
    
    new_header = df_cat.iloc[0] # grab the first row for the header
    df_cat = df_cat[1:] # take the data minus the header row
    df_cat.columns = new_header
  
    df_cat['% of non_subscriber pvs'] = (df_cat['non_subscriber'] / df_cat['non_subscriber'].sum()) * 100
    df_cat['% of subscriber pvs'] = (df_cat['subscriber'] / df_cat['subscriber'].sum()) * 100
    
    df_cat.drop(['non_subscriber', 'subscriber'], axis=1, inplace=True)

    df_cat['non_subscriber_rank'] = df_cat['% of non_subscriber pvs'].rank(ascending=False).astype(int)
    df_cat['subscriber_rank'] = df_cat['% of subscriber pvs'].rank(ascending=False).astype(int)

    df_cat = df_cat.sort_values('subscriber_rank')
    
    return df_cat

# %%
def top_eda(df):
    '''
    Prep df for eda
    '''
    # remove column = "none" i.e. Tier 1/Tier2/PC/PS was not available
    df.drop("none", axis=1, inplace=True)
    
    # group all subscribers, calculate mean of their (avg. time on page) for each category. Same for Non-subscribers
    df = df.groupby('subscription_status').mean().T
    
    # assign rank
    df['non_subscriber_rank'] = df['non_subscriber'].rank(ascending=False).astype(int)
    df['subscriber_rank'] = df['subscriber'].rank(ascending=False).astype(int)
    df = df.sort_values('subscriber_rank')

    return df

# %% [markdown]
# ## DATA

# %%
start_time = time.time()

query_string = """
  SELECT
       *
    FROM
        `api-project-901373404215.skt.subscriber_ga_data`
"""

subs_data = (
    bqclient.query(query_string)
    .result()
    .to_dataframe(bqstorage_client=bqstorageclient)
) 

print("--- %s seconds ---" % (time.time() - start_time))

subs_data["subscription_status"] = "subscriber"

# drop unnecessary col & rename
subs_data.drop(['user_id_uid', 'resource_id_rid'], axis=1, inplace=True)
subs_data.rename(columns={'ga_pianoId': 'piano_id'}, inplace=True)

# drop dups
subs_data.drop_duplicates(keep='first', inplace=True)
print("Duplicates?: ", subs_data.duplicated().any())


print(subs_data.shape)
print("Unique unlimited subscribers: ", len(subs_data.piano_id.unique()))
print("Unique unlimited fullvids: ", len(subs_data.GA_fullVisitorId.unique()), "\n")

subs_data.head()
# Out:
# --- 24.56462812423706 seconds ---
# (6588071, 23)
# Unique unlimited subscribers:  42678
# Unique unlimited fullvids:  101600
#
# Duplicates?:  False
#           piano_id     GA_fullVisitorId  GA_visitStartTime     GA_date  \
# 0  pniuojdbxqsjc3h  6969734970922600880         1629730389  2021-08-23
# 1  pnicghdflqmfx7t  6375914690944396875         1609814826  2021-01-04
# 2  pniy7r900qn3sir  6642711071460721994         1610927979  2021-01-17
# 3  pnihyef2cqjnevq   781170581791183074         1617029229  2021-03-29
# 4  pniagcmbwqjw92n  3644467403674640393         1632406065  2021-09-23
#
#                                          GA_pagePath  \
# 0  /sites/jackkelly/2021/08/15/the-remote-trend-o...
# 1  /sites/kwamechristian/2021/01/04/how-to-handle...
# 2  /sites/nicolebendaly/2021/01/03/three-things-t...
# 3  /sites/danabrownlee/2021/03/28/increasingly-co...
# 4  /sites/kathycaprino/2021/09/20/6-key-ways-lead...
#
#                      GA_dfpNewZone  GA_visitNumber  GA_pageViews  \
# 0  article/standard/subscriber/alx              61             1
# 1  article/standard/subscriber/alx               3             1
# 2  article/standard/subscriber/alx               8             1
# 3  article/standard/subscriber/alx            1007             1
# 4  article/standard/subscriber/alx              63             1
#
#    GA_scrollDepth  timeOnPage  ... GA_deviceOperatingSystem GA_deviceCategory  \
# 0            1.00       33.00  ...                  windows           desktop
# 1            0.25      783.00  ...                  windows           desktop
# 2            0.75      306.00  ...                  windows           desktop
# 3            0.50        8.00  ...                  windows           desktop
# 4            0.75      107.00  ...                macintosh           desktop
#
#   GA_deviceBrowser     GA_country GA_referralGroup GA_primaryChannel  \
# 0           chrome  united states   organic search        leadership
# 1           chrome  united states   organic search        leadership
# 2             edge  united states   organic search        leadership
# 3           chrome  united states   organic search        leadership
# 4           chrome  united states       newsletter        leadership
#
#   GA_primarySection                 tier1       tier2 subscription_status
# 0           careers               Careers  Job Search          subscriber
# 1           careers     News and Politics    Politics          subscriber
# 2           careers  Business and Finance    Business          subscriber
# 3           careers  Business and Finance  Industries          subscriber
# 4           careers  Business and Finance    Business          subscriber
#
# [5 rows x 23 columns]

# %%
start_time = time.time()

query_string = """
  SELECT
       *
    FROM
        `api-project-901373404215.skt.oct_ns_ga_data`
"""

nonsubs_data = (
    bqclient.query(query_string)
    .result()
    .to_dataframe(bqstorage_client=bqstorageclient)
) 

print("--- %s seconds ---" % (time.time() - start_time))

nonsubs_data["subscription_status"] = "non_subscriber"

# drop dups
nonsubs_data.drop_duplicates(keep='first', inplace=True)
print("Duplicates?: ", nonsubs_data.duplicated().any(), "\n")


print("---Before removing suspicious fvids---")
print(nonsubs_data.shape)
print("Unique unlimited fullvids: ", len(nonsubs_data.GA_fullVisitorId.unique()), "\n")

nonsubs_data.GA_dfpNewZone = nonsubs_data.GA_dfpNewZone.fillna('none')
suspicious_fvid = nonsubs_data[nonsubs_data.GA_dfpNewZone.str.contains('/subscriber/')].GA_fullVisitorId.unique()
print("---After removing suspicious fvids---", len(suspicious_fvid))
nonsubs_data = nonsubs_data[~nonsubs_data.GA_fullVisitorId.isin(suspicious_fvid)]
print(nonsubs_data.shape)
print("Unique unlimited fullvids: ", len(nonsubs_data.GA_fullVisitorId.unique()), "\n")


nonsubs_data.head()
# Out:
# --- 11.949727773666382 seconds ---
# Duplicates?:  False
#
# ---Before removing suspicious fvids---
# (4028728, 23)
# Unique unlimited fullvids:  110000
#
# ---After removing suspicious fvids--- 62
# (4014189, 23)
# Unique unlimited fullvids:  109938
#   piano_id      GA_fullVisitorId  GA_visitStartTime     GA_date  \
# 0     None   4883999870040518240         1599485310  2020-09-07
# 1     None  11827268133006795236         1588572447  2020-05-04
# 2     None   8704629655117643411         1595016270  2020-07-17
# 3     None   4959561173344172366         1595700290  2020-07-25
# 4     None   1225431135904108999         1596797370  2020-08-07
#
#                                          GA_pagePath  \
# 0  /sites/robertberger/2020/09/06/when-300-unempl...
# 1  /sites/andrewsolender/2020/05/03/support-in-co...
# 2  /sites/ebauer/2020/07/17/the-social-security-t...
# 3  /sites/zackfriedman/2020/07/24/unemployment-be...
# 4  /sites/zackfriedman/2020/07/22/second-stimulus...
#
#                            GA_dfpNewZone  GA_visitNumber  GA_pageViews  \
# 0   article-amp/advisor/default/standard              97             1
# 1   article-amp/topline/default/standard              40             1
# 2  article-amp/standard/default/standard              43             1
# 3  article-amp/standard/default/standard              11             1
# 4  article-amp/standard/default/standard              10             1
#
#    GA_scrollDepth  timeOnPage  ... GA_deviceOperatingSystem GA_deviceCategory  \
# 0            0.75      141.00  ...                  android            mobile
# 1            0.25       22.00  ...                  android            mobile
# 2             nan      107.00  ...                  android            mobile
# 3            0.00         nan  ...                  android           desktop
# 4            0.00        0.00  ...                  android            mobile
#
#   GA_deviceBrowser     GA_country     GA_referralGroup GA_primaryChannel  \
# 0  android webview  united states  content aggregators             money
# 1  android webview  united states  content aggregators          business
# 2  android webview  united states  content aggregators             money
# 3  android webview  united states  content aggregators             money
# 4  android webview  united states  content aggregators             money
#
#   GA_primarySection             tier1                 tier2  \
# 0  personal finance  Personal Finance  Financial Assistance
# 1            policy  Personal Finance  Financial Assistance
# 2        retirement  Personal Finance  Financial Assistance
# 3  personal finance  Personal Finance  Financial Assistance
# 4  personal finance  Personal Finance  Financial Assistance
#
#   subscription_status
# 0      non_subscriber
# 1      non_subscriber
# 2      non_subscriber
# 3      non_subscriber
# 4      non_subscriber
#
# [5 rows x 23 columns]

# %%
# any col names mismatch? - no

[x for x in list(subs_data.columns) if x not in list(nonsubs_data.columns)]
# Out:
# []

# %%
df = pd.concat([subs_data, nonsubs_data])

print("Shape: ", df.shape)

# fill na
df.GA_cmsNaturalId = df.GA_cmsNaturalId.fillna('None') 

# short list device OS
shortlisted_os = ["android", "ios", "macintosh", "windows"]

df["deviceOS"] = np.where(df["GA_deviceOperatingSystem"].isin(shortlisted_os), 
                          df["GA_deviceOperatingSystem"], 
                          "other")

df[['GA_fullVisitorId', 'subscription_status']].drop_duplicates(keep='first').subscription_status.value_counts()
# Out:
# Shape:  (10602260, 23)
# non_subscriber    109938
# subscriber        101600
# Name: subscription_status, dtype: int64

# %%
df.head()
# Out:
#           piano_id     GA_fullVisitorId  GA_visitStartTime     GA_date  \
# 0  pniuojdbxqsjc3h  6969734970922600880         1629730389  2021-08-23
# 1  pnicghdflqmfx7t  6375914690944396875         1609814826  2021-01-04
# 2  pniy7r900qn3sir  6642711071460721994         1610927979  2021-01-17
# 3  pnihyef2cqjnevq   781170581791183074         1617029229  2021-03-29
# 4  pniagcmbwqjw92n  3644467403674640393         1632406065  2021-09-23
#
#                                          GA_pagePath  \
# 0  /sites/jackkelly/2021/08/15/the-remote-trend-o...
# 1  /sites/kwamechristian/2021/01/04/how-to-handle...
# 2  /sites/nicolebendaly/2021/01/03/three-things-t...
# 3  /sites/danabrownlee/2021/03/28/increasingly-co...
# 4  /sites/kathycaprino/2021/09/20/6-key-ways-lead...
#
#                      GA_dfpNewZone  GA_visitNumber  GA_pageViews  \
# 0  article/standard/subscriber/alx              61             1
# 1  article/standard/subscriber/alx               3             1
# 2  article/standard/subscriber/alx               8             1
# 3  article/standard/subscriber/alx            1007             1
# 4  article/standard/subscriber/alx              63             1
#
#    GA_scrollDepth  timeOnPage  ... GA_deviceCategory GA_deviceBrowser  \
# 0            1.00       33.00  ...           desktop           chrome
# 1            0.25      783.00  ...           desktop           chrome
# 2            0.75      306.00  ...           desktop             edge
# 3            0.50        8.00  ...           desktop           chrome
# 4            0.75      107.00  ...           desktop           chrome
#
#       GA_country GA_referralGroup GA_primaryChannel GA_primarySection  \
# 0  united states   organic search        leadership           careers
# 1  united states   organic search        leadership           careers
# 2  united states   organic search        leadership           careers
# 3  united states   organic search        leadership           careers
# 4  united states       newsletter        leadership           careers
#
#                   tier1       tier2 subscription_status   deviceOS
# 0               Careers  Job Search          subscriber    windows
# 1     News and Politics    Politics          subscriber    windows
# 2  Business and Finance    Business          subscriber    windows
# 3  Business and Finance  Industries          subscriber    windows
# 4  Business and Finance    Business          subscriber  macintosh
#
# [5 rows x 24 columns]

# %%
target_class = df[['GA_fullVisitorId', 'subscription_status']].drop_duplicates(keep='first')

# %% [markdown]
# ### User's whole behavior
# **i.e., avg. top and sum(pvs) over whole GA history**

# %%
whole = df.groupby(['GA_fullVisitorId', 'subscription_status']).agg({'GA_pageViews': 'sum', 'timeOnPage': 'sum'}).reset_index().rename(columns={'GA_pageViews': 'sum_pvs'})
whole["avg_top"] = whole['timeOnPage']/whole['sum_pvs']

whole
# Out:
#             GA_fullVisitorId subscription_status  sum_pvs  timeOnPage  avg_top
# 0       10000049855779198375      non_subscriber        3      244.00    81.33
# 1       10000168040775107380      non_subscriber       35     2153.00    61.51
# 2       10000181072003986570      non_subscriber       11      392.00    35.64
# 3       10000796870131167689      non_subscriber        6      629.00   104.83
# 4        1000096511026234346          subscriber       25     1781.00    71.24
# ...                      ...                 ...      ...         ...      ...
# 211533   9999523824842481160      non_subscriber       13     1194.00    91.85
# 211534   9999640204191429572      non_subscriber        9       81.00     9.00
# 211535   9999943173698081042      non_subscriber       17     2529.00   148.76
# 211536   9999987496363756221      non_subscriber       43     5256.00   122.23
# 211537   9999987504359326751      non_subscriber        6      722.00   120.33
#
# [211538 rows x 5 columns]

# %% [markdown]
# * Distribution of sum(pvs)
#     * Even after limiting non-subs with >5 articles, on a whole -- subs have more pvs than non-subs (except extreme values)

# %%
whole.groupby('subscription_status').sum_pvs.describe().T
# Out:
# subscription_status  non_subscriber  subscriber
# count                     109938.00   101600.00
# mean                          36.51       64.84
# std                           96.72      246.40
# min                            1.00        1.00
# 25%                            6.00        7.00
# 50%                           11.00       18.00
# 75%                           24.00       46.00
# max                         3797.00    22371.00

# %% [markdown]
# * Distribution of avg(top)
#     * Subs spend more avg. top than non-subs on a whole

# %%
whole.groupby('subscription_status').avg_top.describe().T
# Out:
# subscription_status  non_subscriber  subscriber
# count                     109938.00   101600.00
# mean                          84.95      138.57
# std                           77.21      105.15
# min                            0.00        0.00
# 25%                           35.41       68.00
# 50%                           66.14      117.90
# 75%                          109.93      181.85
# max                         1261.60     2497.00

# %% [markdown]
# ### Users' Unique Pageviews in each session (avg, median)

# %%
# user's per pagepath GA data
page = df.groupby(['GA_fullVisitorId', 'GA_visitStartTime', 'GA_pagePath']).agg({'GA_pageViews': 'max', 'GA_scrollDepth': 'max', 'timeOnPage': 'sum'}).reset_index()

# user's per session GA data
session = page.groupby(['GA_fullVisitorId', 'GA_visitStartTime']).agg({'GA_pageViews': 'sum', 'GA_scrollDepth': 'mean', 'timeOnPage': 'mean'}).reset_index()

session.rename(columns={'GA_pageViews': 'unique_pageViews', 'timeOnPage': 'top_per_session'}, inplace=True)
session
# Out:
#              GA_fullVisitorId  GA_visitStartTime  unique_pageViews  \
# 0        10000049855779198375         1633875633                 1
# 1        10000049855779198375         1634090973                 1
# 2        10000049855779198375         1634130400                 1
# 3        10000168040775107380         1628320080                 1
# 4        10000168040775107380         1628441132                 1
# ...                       ...                ...               ...
# 6952743   9999987504359326751         1634442610                 1
# 6952744   9999987504359326751         1634898404                 1
# 6952745   9999987504359326751         1635315690                 1
# 6952746   9999987504359326751         1635637982                 1
# 6952747   9999987504359326751         1635640567                 1
#
#          GA_scrollDepth  top_per_session
# 0                  0.50           176.00
# 1                  0.50            68.00
# 2                  0.00             0.00
# 3                  0.75            12.00
# 4                  0.25            22.00
# ...                 ...              ...
# 6952743            0.50            48.00
# 6952744            0.50           159.00
# 6952745            0.75           173.00
# 6952746            0.75           329.00
# 6952747            0.50             0.00
#
# [6952748 rows x 5 columns]

# %% [markdown]
# * Average and Median of (unique pageviews in each sessions)

# %%
pageViews = session.groupby('GA_fullVisitorId').agg({'unique_pageViews': ['mean', 'median']}).reset_index()

# rename cols
pageViews.columns = [' '.join(col).strip() for col in pageViews.columns.values]
pageViews.rename(columns={'unique_pageViews mean':'unique_pageviews_mean', 'unique_pageViews median': 'unique_pageviews_median'}, inplace=True)

# join target class
pageViews = pd.merge(pageViews, target_class, how="left", on = "GA_fullVisitorId")
pageViews
# Out:
#             GA_fullVisitorId  unique_pageviews_mean  unique_pageviews_median  \
# 0       10000049855779198375                   1.00                     1.00
# 1       10000168040775107380                   1.06                     1.00
# 2       10000181072003986570                   1.00                     1.00
# 3       10000796870131167689                   1.00                     1.00
# 4        1000096511026234346                   3.00                     2.50
# ...                      ...                    ...                      ...
# 211533   9999523824842481160                   1.00                     1.00
# 211534   9999640204191429572                   1.00                     1.00
# 211535   9999943173698081042                   1.07                     1.00
# 211536   9999987496363756221                   1.07                     1.00
# 211537   9999987504359326751                   1.00                     1.00
#
#        subscription_status
# 0           non_subscriber
# 1           non_subscriber
# 2           non_subscriber
# 3           non_subscriber
# 4               subscriber
# ...                    ...
# 211533      non_subscriber
# 211534      non_subscriber
# 211535      non_subscriber
# 211536      non_subscriber
# 211537      non_subscriber
#
# [211538 rows x 4 columns]

# %%
pageViews.groupby('subscription_status').unique_pageviews_mean.describe().T
# Out:
# subscription_status  non_subscriber  subscriber
# count                     109938.00   101600.00
# mean                           1.09        2.33
# std                            0.36        4.45
# min                            1.00        1.00
# 25%                            1.00        1.33
# 50%                            1.00        1.75
# 75%                            1.09        2.50
# max                           39.00      356.00

# %%
pageViews.groupby('subscription_status').unique_pageviews_median.describe().T
# Out:
# subscription_status  non_subscriber  subscriber
# count                     109938.00   101600.00
# mean                           1.03        1.88
# std                            0.35        4.43
# min                            1.00        1.00
# 25%                            1.00        1.00
# 50%                            1.00        1.00
# 75%                            1.00        2.00
# max                           39.00      356.00

# %% [markdown]
# ### Users' Time on Page in each session (avg, median)

# %%
timeOnPage = session.groupby('GA_fullVisitorId').agg({'top_per_session': ['mean', 'median']}).reset_index()

# rename cols
timeOnPage.columns = [' '.join(col).strip() for col in timeOnPage.columns.values]
timeOnPage.rename(columns={'top_per_session mean':'top_mean', 'top_per_session median': 'top_median'}, inplace=True)

# join target class
timeOnPage = pd.merge(timeOnPage, target_class, how="left", on = "GA_fullVisitorId")
timeOnPage
# Out:
#             GA_fullVisitorId  top_mean  top_median subscription_status
# 0       10000049855779198375     81.33       68.00      non_subscriber
# 1       10000168040775107380     61.31        0.00      non_subscriber
# 2       10000181072003986570     35.64       17.00      non_subscriber
# 3       10000796870131167689    104.83        5.00      non_subscriber
# 4        1000096511026234346    106.76       49.72          subscriber
# ...                      ...       ...         ...                 ...
# 211533   9999523824842481160     91.85        1.00      non_subscriber
# 211534   9999640204191429572      9.00        0.00      non_subscriber
# 211535   9999943173698081042    140.17       10.00      non_subscriber
# 211536   9999987496363756221    110.76       79.25      non_subscriber
# 211537   9999987504359326751    120.33      103.50      non_subscriber
#
# [211538 rows x 4 columns]

# %% [markdown]
# * Average and Median of (sum of time on page in each session)

# %%
timeOnPage.groupby('subscription_status').top_mean.describe().T
# Out:
# subscription_status  non_subscriber  subscriber
# count                     109938.00   101600.00
# mean                          79.78      143.70
# std                           73.55      126.58
# min                            0.00        0.00
# 25%                           33.67       66.92
# 50%                           61.79      115.57
# 75%                          102.28      183.72
# max                         1266.42     4994.00

# %%
timeOnPage.groupby('subscription_status').top_median.describe().T
# Out:
# subscription_status  non_subscriber  subscriber
# count                     109938.00   101600.00
# mean                          40.73       84.77
# std                           61.29      111.33
# min                            0.00        0.00
# 25%                            5.00       28.17
# 50%                           24.00       56.29
# 75%                           52.50       99.50
# max                         1320.00     4994.00

# %% [markdown]
# ### Pageviews in referral sources, country, device OS

# %%
pvs_eda(df, 'GA_referralGroup')
# Out:
# subscription_status     % of non_subscriber pvs % of subscriber pvs  \
# GA_referralGroup
# organic search                            29.70               66.10
# newsletter                                 0.01                7.95
# referral                                   0.39                7.76
# direct                                     9.28                6.82
# organic social (dark)                      0.77                4.90
# content aggregators                       59.72                3.24
# organic social (forbes)                    0.09                3.13
# paid search                                0.03                0.07
# paid display                               0.00                0.01
# paid web                                   0.00                0.01
# fbia                                       0.00                0.01
# paid social (dark)                         0.00                0.00
# paid social (forbes)                       0.00                0.00
#
# subscription_status      non_subscriber_rank  subscriber_rank
# GA_referralGroup
# organic search                             2                1
# newsletter                                 8                2
# referral                                   5                3
# direct                                     3                4
# organic social (dark)                      4                5
# content aggregators                        1                6
# organic social (forbes)                    6                7
# paid search                                7                8
# paid display                              10                9
# paid web                                   9               10
# fbia                                      12               11
# paid social (dark)                        12               12
# paid social (forbes)                      12               13

# %%
pvs_eda(df, 'GA_country').drop('(not set)').head(10)
# Out:
# subscription_status % of non_subscriber pvs % of subscriber pvs  \
# GA_country
# united states                         66.09               91.29
# canada                                12.06                1.22
# united kingdom                         6.10                1.20
# japan                                  0.17                0.71
# australia                              3.38                0.51
# india                                  1.23                0.42
# singapore                              1.51                0.23
# israel                                 0.12                0.19
# dominican republic                     0.06                0.18
# hong kong                              0.34                0.18
#
# subscription_status  non_subscriber_rank  subscriber_rank
# GA_country
# united states                          1                1
# canada                                 2                2
# united kingdom                         3                3
# japan                                 24                4
# australia                              4                5
# india                                  6                7
# singapore                              5                8
# israel                                32                9
# dominican republic                    44               10
# hong kong                             14               11

# %%
pvs_eda(df, 'deviceOS')
# Out:
# subscription_status % of non_subscriber pvs % of subscriber pvs  \
# deviceOS
# windows                                0.02               43.57
# macintosh                              0.21               39.92
# ios                                   57.28                8.20
# android                               42.45                7.82
# other                                  0.03                0.49
#
# subscription_status  non_subscriber_rank  subscriber_rank
# deviceOS
# windows                                5                1
# macintosh                              3                2
# ios                                    1                3
# android                                2                4
# other                                  4                5

# %%
pvs_eda(df, 'deviceOS')
# Out:
# subscription_status % of non_subscriber pvs % of subscriber pvs  \
# deviceOS
# windows                                0.02               43.57
# macintosh                              0.21               39.92
# ios                                   57.28                8.20
# android                               42.45                7.82
# other                                  0.03                0.49
#
# subscription_status  non_subscriber_rank  subscriber_rank
# deviceOS
# windows                                5                1
# macintosh                              3                2
# ios                                    1                3
# android                                2                4
# other                                  4                5

# %% [markdown]
# ### Pageviews in various content categories
# * Content categories = IAB Tier 1, Tier 2, PC, PS

# %%
content = df.copy()

# extract the start of natid string
content["natid_start"] = content.GA_cmsNaturalId.str.split("/").str[0]

print("Shape before: ", content.shape)

# keep only blogs, slides, magazine
content = content[(content['natid_start'].str.contains('blogandpostid')) | (content['natid_start'].str.contains('blogandslideid')) | (content['natid_start'].str.contains('magazine'))]

print("Shape after: ", content.shape)

# get month-year
content.GA_date = pd.to_datetime(content.GA_date)
content["mon_year"] = content['GA_date'].dt.to_period('M')
# Out:
# Shape before:  (10602260, 25)
# Shape after:  (8661507, 25)

# %%
cat = content.copy()
cat.isna().sum()
# Out:
# piano_id                    3991421
# GA_fullVisitorId                  0
# GA_visitStartTime                 0
# GA_date                           0
# GA_pagePath                       0
# GA_dfpNewZone                235688
# GA_visitNumber                    0
# GA_pageViews                      0
# GA_scrollDepth              1081180
# timeOnPage                   402819
# GA_cmsNaturalId                   0
# title                         31771
# publish_date                  31771
# GA_deviceOperatingSystem          0
# GA_deviceCategory                 0
# GA_deviceBrowser                  0
# GA_country                        0
# GA_referralGroup                  0
# GA_primaryChannel                 0
# GA_primarySection                 0
# tier1                       2311390
# tier2                       2772598
# subscription_status               0
# deviceOS                          0
# natid_start                       0
# mon_year                          0
# dtype: int64

# %%
print("Before - unique PC: ", len(cat.GA_primaryChannel.unique()))
print("Before - unique PS: ", len(cat.GA_primarySection.unique()), "\n")

shortlisted_channel = joblib.load("pri_channel_shortlisted.pkl")
shortlisted_section = joblib.load("pri_section_shortlisted.pkl")

# primary channel
cat["GA_primaryChannel"] = np.where(cat["GA_primaryChannel"].isin(shortlisted_channel), 
                                    cat["GA_primaryChannel"], "other")

# primary section 
cat["GA_primarySection"] = np.where(cat["GA_primarySection"].isin(shortlisted_section), 
                                    cat["GA_primarySection"], "other")

print("After shortlisting - unique PC: ", len(cat.GA_primaryChannel.unique()))
print("After shortlisting - unique PS: ", len(cat.GA_primarySection.unique()), "\n")

# fillna with 0
cat.timeOnPage = cat.timeOnPage.fillna(0)

# replace empty and NULL with "none"
cat.tier1 = cat.tier1.replace(r'^\s*$', "none", regex=True)
cat.tier1 = cat.tier1.fillna("none")

# replace empty and NULL with "none"
cat.tier2 = cat.tier2.replace(r'^\s*$', "none", regex=True)
cat.tier2 = cat.tier2.fillna("none")

print("Unique all T1s: ", len(cat.tier1.unique()))  
print("Unique all T2s: ", len(cat.tier1.unique()))
# Out:
# Before - unique PC:  35
# Before - unique PS:  156
#
# After shortlisting - unique PC:  24
# After shortlisting - unique PS:  51
#
# Unique all T1s:  31
# Unique all T2s:  31

# %%
cat.shape
# Out:
# (8661507, 26)

# %% [markdown]
# * Pageviews - Tier 1

# %%
pvs_eda(cat, 'tier1', drop_cols=True)
# Out:
# subscription_status      % of non_subscriber pvs % of subscriber pvs  \
# tier1
# Business and Finance                       17.03               31.08
# Personal Finance                           15.01               10.51
# News and Politics                          11.95               10.31
# Technology & Computing                     14.42                8.62
# Medical Health                              5.82                7.33
# Video Gaming                               16.18                3.67
# Travel                                      2.19                3.11
# Careers                                     1.18                2.49
# Food & Drink                                0.82                2.21
# Shopping                                    1.02                2.19
# Sports                                      2.00                2.15
# Style & Fashion                             0.82                2.09
# Education                                   0.74                1.78
# Automotive                                  1.41                1.74
# Real Estate                                 0.73                1.49
# Television                                  1.65                1.34
# Movies                                      1.15                1.29
# Events and Attractions                      0.49                1.16
# Science                                     1.78                1.15
# Healthy Living                              0.49                0.90
# Home & Garden                               0.70                0.74
# Music and Audio                             0.74                0.72
# Family and Relationships                    0.23                0.50
# Pop Culture                                 0.36                0.44
# Hobbies & Interests                         0.39                0.32
# Books and Literature                        0.12                0.23
# Fine Art                                    0.17                0.17
# Pets                                        0.19                0.15
# Content Channel                             0.18                0.07
# Religion & Spirituality                     0.03                0.04
#
# subscription_status       non_subscriber_rank  subscriber_rank
# tier1
# Business and Finance                        1                1
# Personal Finance                            3                2
# News and Politics                           5                3
# Technology & Computing                      4                4
# Medical Health                              6                5
# Video Gaming                                2                6
# Travel                                      7                7
# Careers                                    12                8
# Food & Drink                               16                9
# Shopping                                   14               10
# Sports                                      8               11
# Style & Fashion                            15               12
# Education                                  18               13
# Automotive                                 11               14
# Real Estate                                19               15
# Television                                 10               16
# Movies                                     13               17
# Events and Attractions                     22               18
# Science                                     9               19
# Healthy Living                             21               20
# Home & Garden                              20               21
# Music and Audio                            17               22
# Family and Relationships                   25               23
# Pop Culture                                24               24
# Hobbies & Interests                        23               25
# Books and Literature                       29               26
# Fine Art                                   28               27
# Pets                                       26               28
# Content Channel                            27               29
# Religion & Spirituality                    30               30

# %% [markdown]
# * Pageviews - Tier 2

# %%
pvs_eda(cat, 'tier2', drop_cols=True).head(20)
# Out:
# subscription_status     % of non_subscriber pvs % of subscriber pvs  \
# tier2
# Business                                   4.41               18.58
# Industries                                 4.04                8.55
# Computing                                  8.18                6.12
# Politics                                   7.77                6.11
# Economy                                    9.52                5.98
# Diseases and Conditions                    4.11                5.62
# Personal Investing                         5.70                4.96
# Personal Debt                              6.40                2.12
# Travel Type                                1.16                1.93
# Video Game Genres                          6.40                1.83
# Vaccines                                   1.35                1.75
# Law                                        1.81                1.75
# Consumer Electronics                       6.76                1.54
# PC Games                                   8.76                1.34
# Artificial Intelligence                    0.21                1.19
# Personal Taxes                             0.75                1.18
# Auto Type                                  0.90                1.07
# Job Search                                 0.62                1.05
# Remote Working                             0.25                0.93
# College Education                          0.37                0.86
#
# subscription_status      non_subscriber_rank  subscriber_rank
# tier2
# Business                                   9                1
# Industries                                11                2
# Computing                                  3                3
# Politics                                   4                4
# Economy                                    1                5
# Diseases and Conditions                   10                6
# Personal Investing                         8                7
# Personal Debt                              7                8
# Travel Type                               17                9
# Video Game Genres                          6               10
# Vaccines                                  14               11
# Law                                       12               12
# Consumer Electronics                       5               13
# PC Games                                   2               14
# Artificial Intelligence                   45               15
# Personal Taxes                            21               16
# Auto Type                                 18               17
# Job Search                                22               18
# Remote Working                            41               19
# College Education                         28               20

# %% [markdown]
# * Pageviews - Primary Channel

# %%
pvs_eda(cat, 'GA_primaryChannel', drop_cols=True).head(20)
# Out:
# subscription_status % of non_subscriber pvs % of subscriber pvs  \
# GA_primaryChannel
# leadership                             8.48               22.52
# business                              16.96               22.28
# innovation                            38.03               19.80
# money                                 24.02               16.04
# lifestyle                              6.01                8.47
# small business                         0.91                4.11
# billionaires                           0.85                2.00
# real estate                            0.25                0.99
# consumer                               1.29                0.78
# shopping                               0.53                0.77
# asia                                   0.75                0.49
# entrepreneurs                          0.12                0.46
# tech                                   0.66                0.41
# industry                               0.66                0.27
# investing                              0.28                0.27
# newsletters                            0.05                0.13
# opinion                                0.06                0.08
# under 30                               0.01                0.05
# lists                                  0.02                0.03
# video                                  0.00                0.03
#
# subscription_status  non_subscriber_rank  subscriber_rank
# GA_primaryChannel
# leadership                             4                1
# business                               3                2
# innovation                             1                3
# money                                  2                4
# lifestyle                              5                5
# small business                         7                6
# billionaires                           8                7
# real estate                           14                8
# consumer                               6                9
# shopping                              12               10
# asia                                   9               11
# entrepreneurs                         15               12
# tech                                  10               13
# industry                              11               14
# investing                             13               15
# newsletters                           18               16
# opinion                               16               17
# under 30                              20               18
# lists                                 19               19
# video                                 21               20

# %% [markdown]
# * Pageviews - Primary Section

# %%
pvs_eda(cat, 'GA_primarySection', drop_cols=True).head(20)
# Out:
# subscription_status       % of non_subscriber pvs % of subscriber pvs  \
# GA_primarySection
# careers                                      2.54                6.62
# leadership strategy                          2.68                5.93
# games                                       17.85                5.65
# travel                                       2.98                4.73
# forbeswomen                                  1.35                4.69
# markets                                      3.90                4.51
# personal finance                             8.92                4.21
# entrepreneurs                                1.30                3.94
# hollywood & entertainment                    2.94                3.91
# crypto & blockchain                          9.04                3.56
# retail                                       0.66                3.28
# investing                                    2.66                3.21
# cmo network                                  0.33                3.12
# consumer tech                               12.35                2.97
# healthcare                                   2.35                2.32
# taxes                                        0.81                2.32
# sportsmoney                                  2.51                2.30
# enterprise tech                              0.37                1.92
# food & drink                                 0.30                1.80
# education                                    0.86                1.73
#
# subscription_status        non_subscriber_rank  subscriber_rank
# GA_primarySection
# careers                                     13                1
# leadership strategy                         11                2
# games                                        1                3
# travel                                       8                4
# forbeswomen                                 18                5
# markets                                      6                6
# personal finance                             4                7
# entrepreneurs                               19                8
# hollywood & entertainment                    9                9
# crypto & blockchain                          3               10
# retail                                      25               11
# investing                                   12               12
# cmo network                                 33               13
# consumer tech                                2               14
# healthcare                                  15               15
# taxes                                       23               16
# sportsmoney                                 14               17
# enterprise tech                             32               18
# food & drink                                35               19
# education                                   21               20

# %% [markdown]
# ### Avg. TOP in various content categories
# * Content categories = IAB Tier 1, Tier 2

# %%
t1 = cat.pivot_table(index=['GA_fullVisitorId'], 
                     columns='tier1',
                     values=['timeOnPage', 'GA_pageViews'], 
                     aggfunc='sum', 
                     fill_value=0).reset_index()
# set aside fvids
fvids = list(t1.GA_fullVisitorId)

# calc avg. top
t1_top = t1["timeOnPage"]/t1["GA_pageViews"]
t1_top = t1_top.fillna(0)

t1_top["GA_fullVisitorId"] = fvids
t1_top = pd.merge(t1_top, target_class, how="left", on="GA_fullVisitorId")

# %% [markdown]
# * Average time on page - Tier 1

# %%
top_eda(t1_top).rename(columns={'non_subscriber': 'non_subscriber avg. top', 'subscriber': 'subscriber avg. top'})
# Out:
# subscription_status       non_subscriber avg. top  subscriber avg. top  \
# Business and Finance                        45.30               127.88
# Personal Finance                            41.52                83.13
# Technology & Computing                      34.72                70.92
# Medical Health                              22.60                67.06
# News and Politics                           24.12                66.05
# Careers                                     10.51                38.82
# Travel                                      13.20                36.92
# Shopping                                     8.27                32.34
# Style & Fashion                              7.18                31.12
# Sports                                       9.74                29.15
# Education                                    6.31                28.85
# Food & Drink                                 6.14                27.68
# Automotive                                  10.82                27.67
# Real Estate                                  8.01                25.78
# Events and Attractions                       5.09                24.24
# Science                                     12.82                22.63
# Television                                  13.06                22.13
# Healthy Living                               5.21                20.58
# Home & Garden                                8.29                18.73
# Video Gaming                                25.32                15.19
# Family and Relationships                     3.03                14.61
# Movies                                       9.02                14.10
# Music and Audio                              4.99                13.78
# Pop Culture                                  4.26                12.44
# Hobbies & Interests                          4.90                10.10
# Books and Literature                         1.97                 7.84
# Fine Art                                     2.56                 5.52
# Pets                                         2.25                 4.88
# Content Channel                              2.35                 3.17
# Religion & Spirituality                      0.60                 1.92
#
# subscription_status       non_subscriber_rank  subscriber_rank
# Business and Finance                        1                1
# Personal Finance                            2                2
# Technology & Computing                      3                3
# Medical Health                              6                4
# News and Politics                           5                5
# Careers                                    11                6
# Travel                                      7                7
# Shopping                                   15                8
# Style & Fashion                            17                9
# Sports                                     12               10
# Education                                  18               11
# Food & Drink                               19               12
# Automotive                                 10               13
# Real Estate                                16               14
# Events and Attractions                     21               15
# Science                                     9               16
# Television                                  8               17
# Healthy Living                             20               18
# Home & Garden                              14               19
# Video Gaming                                4               20
# Family and Relationships                   25               21
# Movies                                     13               22
# Music and Audio                            22               23
# Pop Culture                                24               24
# Hobbies & Interests                        23               25
# Books and Literature                       29               26
# Fine Art                                   26               27
# Pets                                       28               28
# Content Channel                            27               29
# Religion & Spirituality                    30               30

# %% [markdown]
# * Average time on page - Tier 2

# %%
t2 = cat.pivot_table(index=['GA_fullVisitorId'], 
                     columns='tier2',
                     values=['timeOnPage', 'GA_pageViews'], 
                     aggfunc='sum', 
                     fill_value=0).reset_index()
# set aside fvids
fvids = list(t2.GA_fullVisitorId)

# calc avg. top
t2_top = t2["timeOnPage"]/t2["GA_pageViews"]
t2_top = t2_top.fillna(0)

t2_top["GA_fullVisitorId"] = fvids
t2_top = pd.merge(t2_top, target_class, how="left", on="GA_fullVisitorId")

top_eda(t2_top).rename(columns={'non_subscriber': 'non_subscriber avg. top', 'subscriber': 'subscriber avg. top'}).head(15)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# /tmp/ipykernel_21989/3123860244.py in <module>
#       3                      values=['timeOnPage', 'GA_pageViews'],
#       4                      aggfunc='sum',
# ----> 5                      fill_value=0).reset_index()
#       6 # set aside fvids
#       7 fvids = list(t2.GA_fullVisitorId)
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#    6834             dropna=dropna,
#    6835             margins_name=margins_name,
# -> 6836             observed=observed,
#    6837         )
#    6838
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#     110
#     111     grouped = data.groupby(keys, observed=observed)
# --> 112     agged = grouped.agg(aggfunc)
#     113     if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#     114         agged = agged.dropna(how="all")
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     949         func = maybe_mangle_lambdas(func)
#     950
# --> 951         result, how = self._aggregate(func, *args, **kwargs)
#     952         if how is None:
#     953             return result
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/base.py in _aggregate(self, arg, *args, **kwargs)
#     305
#     306         if isinstance(arg, str):
# --> 307             return self._try_aggregate_string_function(arg, *args, **kwargs), None
#     308
#     309         if isinstance(arg, dict):
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/base.py in _try_aggregate_string_function(self, arg, *args, **kwargs)
#     261         if f is not None:
#     262             if callable(f):
# --> 263                 return f(*args, **kwargs)
#     264
#     265             # people may try to aggregate on a non-callable attribute
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in sum(self, numeric_only, min_count)
#    1540     def sum(self, numeric_only: bool = True, min_count: int = 0):
#    1541         return self._agg_general(
# -> 1542             numeric_only=numeric_only, min_count=min_count, alias="add", npfunc=np.sum
#    1543         )
#    1544
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _agg_general(self, numeric_only, min_count, alias, npfunc)
#     999         try:
#    1000             result = self._cython_agg_general(
# -> 1001                 how=alias, alt=npfunc, numeric_only=numeric_only, min_count=min_count,
#    1002             )
#    1003         except DataError:
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1020     ) -> DataFrame:
#    1021         agg_blocks, agg_items = self._cython_agg_blocks(
# -> 1022             how, alt=alt, numeric_only=numeric_only, min_count=min_count
#    1023         )
#    1024         return self._wrap_agged_blocks(agg_blocks, items=agg_items)
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _cython_agg_blocks(self, how, alt, numeric_only, min_count)
#    1049             try:
#    1050                 result, _ = self.grouper.aggregate(
# -> 1051                     block.values, how, axis=1, min_count=min_count
#    1052                 )
#    1053             except NotImplementedError:
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/groupby/ops.py in aggregate(self, values, how, axis, min_count)
#     590     ) -> Tuple[np.ndarray, Optional[List[str]]]:
#     591         return self._cython_operation(
# --> 592             "aggregate", values, how, axis, min_count=min_count
#     593         )
#     594
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/groupby/ops.py in _cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     523                     "arity of more than 1 is not supported for the 'how' argument"
#     524                 )
# --> 525             out_shape = (self.ngroups,) + values.shape[1:]
#     526
#     527         func, values = self._get_cython_func_and_vals(kind, how, values, is_numeric)
#
# pandas/_libs/properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/groupby/ops.py in ngroups(self)
#     302     @cache_readonly
#     303     def ngroups(self) -> int:
# --> 304         return len(self.result_index)
#     305
#     306     @property
#
# pandas/_libs/properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/groupby/ops.py in result_index(self)
#     315             return self.groupings[0].result_index.rename(self.names[0])
#     316
# --> 317         codes = self.reconstructed_codes
#     318         levels = [ping.result_index for ping in self.groupings]
#     319         result = MultiIndex(
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/groupby/ops.py in reconstructed_codes(self)
#     306     @property
#     307     def reconstructed_codes(self) -> List[np.ndarray]:
# --> 308         codes = self.codes
#     309         comp_ids, obs_ids, _ = self.group_info
#     310         return decons_obs_group_ids(comp_ids, obs_ids, self.shape, codes, xnull=True)
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/groupby/ops.py in codes(self)
#     237     @property
#     238     def codes(self) -> List[np.ndarray]:
# --> 239         return [ping.codes for ping in self.groupings]
#     240
#     241     @property
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/groupby/ops.py in <listcomp>(.0)
#     237     @property
#     238     def codes(self) -> List[np.ndarray]:
# --> 239         return [ping.codes for ping in self.groupings]
#     240
#     241     @property
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/groupby/grouper.py in codes(self)
#     568     def codes(self) -> np.ndarray:
#     569         if self._codes is None:
# --> 570             self._make_codes()
#     571         return self._codes
#     572
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/groupby/grouper.py in _make_codes(self)
#     597                     na_sentinel = -1
#     598                 codes, uniques = algorithms.factorize(
# --> 599                     self.grouper, sort=self.sort, na_sentinel=na_sentinel
#     600                 )
#     601                 uniques = Index(uniques, name=self.name)
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/algorithms.py in factorize(values, sort, na_sentinel, size_hint)
#     700
#     701         codes, uniques = _factorize_array(
# --> 702             values, na_sentinel=na_sentinel, size_hint=size_hint, na_value=na_value
#     703         )
#     704
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/algorithms.py in _factorize_array(values, na_sentinel, size_hint, na_value, mask)
#     509     table = hash_klass(size_hint or len(values))
#     510     uniques, codes = table.factorize(
# --> 511         values, na_sentinel=na_sentinel, na_value=na_value, mask=mask
#     512     )
#     513
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.StringHashTable.factorize()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.StringHashTable._unique()
#
# MemoryError: Unable to allocate 66.1 MiB for an array with shape (8661507,) and data type int64

# %% [markdown]
# ### Avg. article views in each month

# %%
user_per_mon = pd.DataFrame(content.groupby(['GA_fullVisitorId', 'subscription_status', 'mon_year']).GA_cmsNaturalId.count()).reset_index().rename(columns=
                                                                                                                                                   {'GA_cmsNaturalId':'total_article_views'})
user_per_mon
# Out:
#              GA_fullVisitorId subscription_status mon_year  \
# 0        10000058813304965608      non_subscriber  2020-02
# 1        10000058813304965608      non_subscriber  2020-03
# 2        10000058813304965608      non_subscriber  2020-04
# 3        10000058813304965608      non_subscriber  2020-05
# 4        10000058813304965608      non_subscriber  2020-06
# ...                       ...                 ...      ...
# 1038067   9999883233119772718      non_subscriber  2020-01
# 1038068   9999883233119772718      non_subscriber  2020-10
# 1038069   9999883233119772718      non_subscriber  2021-01
# 1038070   9999883233119772718      non_subscriber  2021-05
# 1038071   9999953169198331967      non_subscriber  2021-07
#
#          total_article_views
# 0                          6
# 1                         14
# 2                         13
# 3                         27
# 4                         15
# ...                      ...
# 1038067                    1
# 1038068                    2
# 1038069                    1
# 1038070                    6
# 1038071                    5
#
# [1038072 rows x 4 columns]

# %% [markdown]
# * Avg(articles per month)

# %%
per_mon =  pd.DataFrame(user_per_mon.groupby(['GA_fullVisitorId', 'subscription_status']).total_article_views.mean()).reset_index()

per_mon.GA_cmsNaturalId = per_mon.total_article_views.round()
per_mon
# Out:
#             GA_fullVisitorId subscription_status  total_article_views
# 0       10000058813304965608      non_subscriber                 9.52
# 1       10000251105399450511      non_subscriber                 8.92
# 2       10000610991313890343      non_subscriber                 2.40
# 3        1000096511026234346          subscriber                 6.00
# 4        1000104336364784244          subscriber                 3.81
# ...                      ...                 ...                  ...
# 203780   9999629024408201784      non_subscriber                 2.33
# 203781    999969109989075422      non_subscriber                 2.70
# 203782   9999757056159711694      non_subscriber                11.47
# 203783   9999883233119772718      non_subscriber                 2.20
# 203784   9999953169198331967      non_subscriber                 5.00
#
# [203785 rows x 3 columns]

# %%
per_mon.groupby('subscription_status').total_article_views.describe().T
# Out:
# subscription_status  non_subscriber  subscriber
# count                     109738.00    94047.00
# mean                           6.44       13.69
# std                            9.54       30.80
# min                            1.39        1.00
# 25%                            3.50        4.50
# 50%                            5.00        8.00
# 75%                            7.00       15.00
# max                         2064.80     3740.00

# %%
# example non-subs
user_per_mon[user_per_mon.GA_fullVisitorId=='10000058813304965608']
# Out:
#         GA_fullVisitorId subscription_status mon_year  GA_cmsNaturalId
# 0   10000058813304965608      non_subscriber  2020-02                6
# 1   10000058813304965608      non_subscriber  2020-03               14
# 2   10000058813304965608      non_subscriber  2020-04               13
# 3   10000058813304965608      non_subscriber  2020-05               27
# 4   10000058813304965608      non_subscriber  2020-06               15
# 5   10000058813304965608      non_subscriber  2020-07                9
# 6   10000058813304965608      non_subscriber  2020-08                1
# 7   10000058813304965608      non_subscriber  2020-09               13
# 8   10000058813304965608      non_subscriber  2020-10               23
# 9   10000058813304965608      non_subscriber  2020-11               13
# 10  10000058813304965608      non_subscriber  2020-12                7
# 11  10000058813304965608      non_subscriber  2021-01               11
# 12  10000058813304965608      non_subscriber  2021-02               15
# 13  10000058813304965608      non_subscriber  2021-03                5
# 14  10000058813304965608      non_subscriber  2021-04                6
# 15  10000058813304965608      non_subscriber  2021-05                4
# 16  10000058813304965608      non_subscriber  2021-06                3
# 17  10000058813304965608      non_subscriber  2021-07                9
# 18  10000058813304965608      non_subscriber  2021-08                4
# 19  10000058813304965608      non_subscriber  2021-09                1
# 20  10000058813304965608      non_subscriber  2021-10                1

# %%
# example subs
user_per_mon[user_per_mon.GA_fullVisitorId=='3857395123229566996']
# Out:
#            GA_fullVisitorId subscription_status mon_year  GA_cmsNaturalId
# 491055  3857395123229566996          subscriber  2020-03                2
# 491056  3857395123229566996          subscriber  2020-04               10
# 491057  3857395123229566996          subscriber  2020-05                5
# 491058  3857395123229566996          subscriber  2020-06               12
# 491059  3857395123229566996          subscriber  2020-07                8
# 491060  3857395123229566996          subscriber  2020-08                9
# 491061  3857395123229566996          subscriber  2020-09                1
# 491062  3857395123229566996          subscriber  2020-10               10
# 491063  3857395123229566996          subscriber  2020-11                8
# 491064  3857395123229566996          subscriber  2020-12               17
# 491065  3857395123229566996          subscriber  2021-01                4
# 491066  3857395123229566996          subscriber  2021-02               10
# 491067  3857395123229566996          subscriber  2021-03               10

# %%
# example subs
user_per_mon[user_per_mon.GA_fullVisitorId=='5277846215104667271']
# Out:
#            GA_fullVisitorId subscription_status mon_year  GA_cmsNaturalId
# 627088  5277846215104667271          subscriber  2020-03                3
# 627089  5277846215104667271          subscriber  2020-04               38
# 627090  5277846215104667271          subscriber  2020-05               34
# 627091  5277846215104667271          subscriber  2020-06               96
# 627092  5277846215104667271          subscriber  2020-07               38
# 627093  5277846215104667271          subscriber  2020-08               69
# 627094  5277846215104667271          subscriber  2020-09               42
# 627095  5277846215104667271          subscriber  2020-10               55
# 627096  5277846215104667271          subscriber  2020-11               73
# 627097  5277846215104667271          subscriber  2020-12              109
# 627098  5277846215104667271          subscriber  2021-01              145
# 627099  5277846215104667271          subscriber  2021-02               48
# 627100  5277846215104667271          subscriber  2021-03              150
# 627101  5277846215104667271          subscriber  2021-04               78
# 627102  5277846215104667271          subscriber  2021-05               81
# 627103  5277846215104667271          subscriber  2021-06               10
# 627104  5277846215104667271          subscriber  2021-07               11

# %%
# joining with C-levels for curiosity

start_time = time.time()

sql = """
    SELECT 
        *
      FROM (
        SELECT 
            DISTINCT *,
            RANK() OVER (PARTITION BY GA_fullVisitorId ORDER BY date DESC) AS mostrecent,
        FROM
            `api-project-901373404215.lookalike.zoom_info_c_level`
          )
      WHERE 
          mostrecent = 1
"""

clevels = (
    bqclient.query(sql)
    .result()
    .to_dataframe(bqstorage_client=bqstorageclient)
) 

print("--- %s seconds ---" % (time.time() - start_time)) #12.45

# %%
clevels
