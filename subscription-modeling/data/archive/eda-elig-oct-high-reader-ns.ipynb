# %%
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.2f' % x)
import numpy as np
from google.cloud import bigquery
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style('darkgrid')
import joblib
import warnings
warnings.filterwarnings('ignore') 
import re

bq_client = bigquery.Client()

# %%
import google.auth
from google.cloud import bigquery
from google.cloud import bigquery_storage
import time

bqclient = bigquery.Client()
bqstorageclient = bigquery_storage.BigQueryReadClient()

# %%
def pvs_eda(input_df, cat_col_name, drop_cols=False):
    
    # pivot
    df_cat = pd.pivot_table(
        input_df, 
        values='GA_pageViews',
        columns= cat_col_name,
        index='subscription_status',
        aggfunc='sum')\
        .reset_index()
    
    # drop none and other cols
    if drop_cols==True:
        
        if 'none' in list(df_cat.columns):
            df_cat.drop('none', axis=1, inplace=True)
        
        if 'other' in list(df_cat.columns):
            df_cat.drop('other', axis=1, inplace=True)

    
    # percentage calc below
    df_cat = df_cat.fillna(0)
    df_cat = df_cat.T
    
    new_header = df_cat.iloc[0] # grab the first row for the header
    df_cat = df_cat[1:] # take the data minus the header row
    df_cat.columns = new_header
  
    df_cat['% of non_subscriber pvs'] = (df_cat['non_subscriber'] / df_cat['non_subscriber'].sum()) * 100
    df_cat['% of subscriber pvs'] = (df_cat['subscriber'] / df_cat['subscriber'].sum()) * 100
    
    df_cat.drop(['non_subscriber', 'subscriber'], axis=1, inplace=True)

    df_cat['non_subscriber_rank'] = df_cat['% of non_subscriber pvs'].rank(ascending=False).astype(int)
    df_cat['subscriber_rank'] = df_cat['% of subscriber pvs'].rank(ascending=False).astype(int)

    df_cat = df_cat.sort_values('subscriber_rank')
    
    return df_cat

# %%
def top_eda(df):
    '''
    Prep df for eda
    '''
    # remove column = "none" i.e. Tier 1/Tier2/PC/PS was not available
    df.drop("none", axis=1, inplace=True)
    
    # group all subscribers, calculate mean of their (avg. time on page) for each category. Same for Non-subscribers
    df = df.groupby('subscription_status').mean().T
    
    # assign rank
    df['non_subscriber_rank'] = df['non_subscriber'].rank(ascending=False).astype(int)
    df['subscriber_rank'] = df['subscriber'].rank(ascending=False).astype(int)
    df = df.sort_values('subscriber_rank')

    return df

# %% [markdown]
# ## DATA

# %%
start_time = time.time()

query_string = """
  SELECT
       *
    FROM
        `api-project-901373404215.skt.subscriber_ga_data`
"""

subs_data = (
    bqclient.query(query_string)
    .result()
    .to_dataframe(bqstorage_client=bqstorageclient)
) 

print("--- %s seconds ---" % (time.time() - start_time))

subs_data["subscription_status"] = "subscriber"

# drop unnecessary col & rename
subs_data.drop(['user_id_uid', 'resource_id_rid'], axis=1, inplace=True)
subs_data.rename(columns={'ga_pianoId': 'piano_id'}, inplace=True)

print(subs_data.shape)
print("Unique unlimited subscribers: ", len(subs_data.piano_id.unique()))
print("Unique unlimited fullvids: ", len(subs_data.GA_fullVisitorId.unique()), "\n")

subs_data.head()
# Out:
# --- 17.195920944213867 seconds ---
# (9746613, 23)
# Unique unlimited subscribers:  42678
# Unique unlimited fullvids:  101600
#           piano_id     GA_fullVisitorId  GA_visitStartTime     GA_date  \
# 0  pnijq8uahqt1sr8  2734608745588682044         1632679824  2021-09-26
# 1  pniptkdboqj82qy  3206243803054980323         1632683536  2021-09-26
# 2  pnijvkirpqja131  6647027608060961839         1624973889  2021-06-29
# 3  pni6ssai9qjzzxh  4724604073189409071         1620156871  2021-05-04
# 4  pniuojdbxqsjc3h  6969734970922600880         1631108312  2021-09-08
#
#                                          GA_pagePath  \
# 0  /sites/kathycaprino/2021/09/20/6-key-ways-lead...
# 1  /sites/jackkelly/2021/09/26/the-future-of-hybr...
# 2  /sites/lucianapaulise/2021/06/29/some-52-of-em...
# 3  /sites/jackkelly/2021/04/21/general-motors-the...
# 4  /sites/markcperna/2021/08/10/4-strategies-for-...
#
#                      GA_dfpNewZone  GA_visitNumber  GA_pageViews  \
# 0  article/standard/subscriber/alx             147             1
# 1  article/standard/subscriber/alx             279             1
# 2  article/standard/subscriber/alx             535             1
# 3  article/standard/subscriber/alx              87             1
# 4  article/standard/subscriber/alx              67             1
#
#    GA_scrollDepth  timeOnPage  ... GA_deviceOperatingSystem GA_deviceCategory  \
# 0             NaN        5.00  ...                  windows           desktop
# 1            1.00       35.00  ...                  windows           desktop
# 2            0.50       13.00  ...                macintosh           desktop
# 3            0.50      611.00  ...                macintosh           desktop
# 4            1.00      116.00  ...                  windows           desktop
#
#   GA_deviceBrowser     GA_country GA_referralGroup GA_primaryChannel  \
# 0             edge  united states       newsletter        leadership
# 1             edge  united states   organic search        leadership
# 2           chrome  united states   organic search        leadership
# 3           chrome  united states   organic search        leadership
# 4           chrome  united states   organic search        leadership
#
#   GA_primarySection                   tier1           tier2  \
# 0           careers    Business and Finance        Business
# 1           careers  Technology & Computing       Computing
# 2           careers                 Careers  Remote Working
# 3           careers    Business and Finance      Industries
# 4           careers    Business and Finance        Business
#
#   subscription_status
# 0          subscriber
# 1          subscriber
# 2          subscriber
# 3          subscriber
# 4          subscriber
#
# [5 rows x 23 columns]

# %%
start_time = time.time()

query_string = """
  SELECT
       *
    FROM
        `api-project-901373404215.skt.all_elig_ns_ga_data`
"""

nonsubs_data = (
    bqclient.query(query_string)
    .result()
    .to_dataframe(bqstorage_client=bqstorageclient)
) 

print("--- %s seconds ---" % (time.time() - start_time))

nonsubs_data["subscription_status"] = "non_subscriber"

print("---Before removing suspicious fvids---")
print(nonsubs_data.shape)
print("Unique unlimited fullvids: ", len(nonsubs_data.GA_fullVisitorId.unique()), "\n")

nonsubs_data.GA_dfpNewZone = nonsubs_data.GA_dfpNewZone.fillna('none')
suspicious_fvid = nonsubs_data[nonsubs_data.GA_dfpNewZone.str.contains('/subscriber/')].GA_fullVisitorId.unique()
print("---After removing suspicious fvids---", len(suspicious_fvid))
nonsubs_data = nonsubs_data[~nonsubs_data.GA_fullVisitorId.isin(suspicious_fvid)]
print(nonsubs_data.shape)
print("Unique unlimited fullvids: ", len(nonsubs_data.GA_fullVisitorId.unique()), "\n")


nonsubs_data.head()
# Out:
# --- 27.787716150283813 seconds ---
# ---Before removing suspicious fvids---
# (15944870, 23)
# Unique unlimited fullvids:  402533
#
# ---After removing suspicious fvids--- 226
# (15819504, 23)
# Unique unlimited fullvids:  402307
#   piano_id     GA_fullVisitorId  GA_visitStartTime     GA_date  \
# 0     None  5787597410793801006         1573219646  2019-11-08
# 1     None  3376429588497101262         1576659613  2019-12-18
# 2     None  2789422896167405547         1565434487  2019-08-10
# 3     None  7508104229272451575         1548639598  2019-01-27
# 4     None  6220182084376833655         1534964621  2018-08-22
#
#                                          GA_pagePath GA_dfpNewZone  \
# 0  /sites/forbesdigitalcovers/2019/11/08/jim-simo...          none
# 1  /sites/peterjreilly/2019/12/17/100b-in-mormon-...          none
# 2  /sites/daveywinder/2019/08/10/apples-iphone-fa...          none
# 3  /sites/davidphelan/2019/01/27/airpods-2-reveal...          none
# 4  /sites/mitsubishiheavyindustries/2018/06/29/se...          none
#
#    GA_visitNumber  GA_pageViews  GA_scrollDepth  timeOnPage  ...  \
# 0             123             1            1.00      399.00  ...
# 1             890             1            0.75      750.00  ...
# 2             128             1            0.75      208.00  ...
# 3             160             1             NaN         NaN  ...
# 4              78             1             NaN         NaN  ...
#
#   GA_deviceOperatingSystem GA_deviceCategory GA_deviceBrowser     GA_country  \
# 0                      ios            mobile  safari (in-app)  united states
# 1                      ios            mobile  safari (in-app)  united states
# 2                      ios            mobile  safari (in-app)         canada
# 3                      ios            mobile  safari (in-app)  united states
# 4                      ios            mobile  safari (in-app)         canada
#
#       GA_referralGroup GA_primaryChannel GA_primarySection tier1 tier2  \
# 0  content aggregators          industry              none  None  None
# 1  content aggregators             money             taxes  None  None
# 2  content aggregators        innovation     cybersecurity  None  None
# 3  content aggregators        innovation     consumer tech  None  None
# 4  content aggregators          business              none  None  None
#
#   subscription_status
# 0      non_subscriber
# 1      non_subscriber
# 2      non_subscriber
# 3      non_subscriber
# 4      non_subscriber
#
# [5 rows x 23 columns]

# %%
# any col names mismatch? - no

[x for x in list(subs_data.columns) if x not in list(nonsubs_data.columns)]
# Out:
# []

# %%
df = pd.concat([subs_data, nonsubs_data])

print("Shape: ", df.shape)

# fill na
df.GA_cmsNaturalId = df.GA_cmsNaturalId.fillna('None') 

# short list device OS
shortlisted_os = ["android", "ios", "macintosh", "windows"]

df["deviceOS"] = np.where(df["GA_deviceOperatingSystem"].isin(shortlisted_os), 
                          df["GA_deviceOperatingSystem"], 
                          "other")

df[['GA_fullVisitorId', 'subscription_status']].drop_duplicates(keep='first').subscription_status.value_counts()
# Out:
# Shape:  (25566117, 23)
# non_subscriber    402307
# subscriber        101600
# Name: subscription_status, dtype: int64

# %%
df[['GA_fullVisitorId', 'subscription_status']].drop_duplicates(keep='first').subscription_status.value_counts(normalize=True)
# Out:
# non_subscriber   0.80
# subscriber       0.20
# Name: subscription_status, dtype: float64

# %%
df.head()
# Out:
#           piano_id     GA_fullVisitorId  GA_visitStartTime     GA_date  \
# 0  pnijq8uahqt1sr8  2734608745588682044         1632679824  2021-09-26
# 1  pniptkdboqj82qy  3206243803054980323         1632683536  2021-09-26
# 2  pnijvkirpqja131  6647027608060961839         1624973889  2021-06-29
# 3  pni6ssai9qjzzxh  4724604073189409071         1620156871  2021-05-04
# 4  pniuojdbxqsjc3h  6969734970922600880         1631108312  2021-09-08
#
#                                          GA_pagePath  \
# 0  /sites/kathycaprino/2021/09/20/6-key-ways-lead...
# 1  /sites/jackkelly/2021/09/26/the-future-of-hybr...
# 2  /sites/lucianapaulise/2021/06/29/some-52-of-em...
# 3  /sites/jackkelly/2021/04/21/general-motors-the...
# 4  /sites/markcperna/2021/08/10/4-strategies-for-...
#
#                      GA_dfpNewZone  GA_visitNumber  GA_pageViews  \
# 0  article/standard/subscriber/alx             147             1
# 1  article/standard/subscriber/alx             279             1
# 2  article/standard/subscriber/alx             535             1
# 3  article/standard/subscriber/alx              87             1
# 4  article/standard/subscriber/alx              67             1
#
#    GA_scrollDepth  timeOnPage  ... GA_deviceCategory GA_deviceBrowser  \
# 0             NaN        5.00  ...           desktop             edge
# 1            1.00       35.00  ...           desktop             edge
# 2            0.50       13.00  ...           desktop           chrome
# 3            0.50      611.00  ...           desktop           chrome
# 4            1.00      116.00  ...           desktop           chrome
#
#       GA_country GA_referralGroup GA_primaryChannel GA_primarySection  \
# 0  united states       newsletter        leadership           careers
# 1  united states   organic search        leadership           careers
# 2  united states   organic search        leadership           careers
# 3  united states   organic search        leadership           careers
# 4  united states   organic search        leadership           careers
#
#                     tier1           tier2 subscription_status   deviceOS
# 0    Business and Finance        Business          subscriber    windows
# 1  Technology & Computing       Computing          subscriber    windows
# 2                 Careers  Remote Working          subscriber  macintosh
# 3    Business and Finance      Industries          subscriber  macintosh
# 4    Business and Finance        Business          subscriber    windows
#
# [5 rows x 24 columns]

# %%
target_class = df[['GA_fullVisitorId', 'subscription_status']].drop_duplicates(keep='first')

# %% [markdown]
# ### User's whole behavior
# **i.e., avg. top and sum(pvs) over whole GA history**

# %%
whole = df.groupby(['GA_fullVisitorId', 'subscription_status']).agg({'GA_pageViews': 'sum', 'timeOnPage': 'sum'}).reset_index().rename(columns={'GA_pageViews': 'sum_pvs'})
whole["avg_top"] = whole['timeOnPage']/whole['sum_pvs']

whole
# Out:
#             GA_fullVisitorId subscription_status  sum_pvs  timeOnPage  avg_top
# 0       10000049855779198375      non_subscriber        6      664.00   110.67
# 1       10000110541771159873      non_subscriber       34     3281.00    96.50
# 2       10000113274638268984      non_subscriber        6      666.00   111.00
# 3       10000130814584242881      non_subscriber       94     2892.00    30.77
# 4       10000151329276278902      non_subscriber        5      419.00    83.80
# ...                      ...                 ...      ...         ...      ...
# 503902   9999886779021615610      non_subscriber       10      657.00    65.70
# 503903   9999921172181296837      non_subscriber       22     1503.00    68.32
# 503904   9999943173698081042      non_subscriber       26     3410.00   131.15
# 503905   9999987496363756221      non_subscriber       43     5256.00   122.23
# 503906   9999987504359326751      non_subscriber        7     1051.00   150.14
#
# [503907 rows x 5 columns]

# %% [markdown]
# * Distribution of sum(pvs)
#     * Even after limiting non-subs with >5 articles, on a whole -- subs have more pvs than non-subs

# %%
whole.groupby('subscription_status').sum_pvs.describe().T
# Out:
# subscription_status  non_subscriber  subscriber
# count                     402307.00   101600.00
# mean                          39.32       95.93
# std                          103.00      616.55
# min                            5.00        1.00
# 25%                            7.00       10.00
# 50%                           12.00       24.00
# 75%                           27.00       65.00
# max                         7709.00    76285.00

# %% [markdown]
# * Distribution of avg(top)
#     * Subs spend more avg. top than non-subs on a whole

# %%
whole.groupby('subscription_status').avg_top.describe().T
# Out:
# subscription_status  non_subscriber  subscriber
# count                     402307.00   101600.00
# mean                          92.61      138.33
# std                           86.06      103.77
# min                            0.00        0.00
# 25%                           36.81       68.00
# 50%                           70.13      118.27
# 75%                          119.70      181.84
# max                         1261.60     2497.00

# %% [markdown]
# ### Users' Unique Pageviews in each session (avg, median)

# %%
# user's per pagepath GA data
page = df.groupby(['GA_fullVisitorId', 'GA_visitStartTime', 'GA_pagePath']).agg({'GA_pageViews': 'max', 'GA_scrollDepth': 'max', 'timeOnPage': 'sum'}).reset_index()

# user's per session GA data
session = page.groupby(['GA_fullVisitorId', 'GA_visitStartTime']).agg({'GA_pageViews': 'sum', 'GA_scrollDepth': 'mean', 'timeOnPage': 'mean'}).reset_index()

session.rename(columns={'GA_pageViews': 'unique_pageViews', 'timeOnPage': 'top_per_session'}, inplace=True)
session 
#3mins
# Out:
#               GA_fullVisitorId  GA_visitStartTime  unique_pageViews  \
# 0         10000049855779198375         1633875633                 1
# 1         10000049855779198375         1634090973                 1
# 2         10000049855779198375         1634130400                 1
# 3         10000110541771159873         1626322032                 1
# 4         10000110541771159873         1626926009                 1
# ...                        ...                ...               ...
# 16793979   9999987504359326751         1634442610                 1
# 16793980   9999987504359326751         1634898404                 1
# 16793981   9999987504359326751         1635315690                 1
# 16793982   9999987504359326751         1635637982                 1
# 16793983   9999987504359326751         1635640567                 1
#
#           GA_scrollDepth  top_per_session
# 0                   0.50           528.00
# 1                   0.50           136.00
# 2                   0.00             0.00
# 3                   0.25            22.00
# 4                   0.50            57.00
# ...                  ...              ...
# 16793979            0.50            48.00
# 16793980            0.50           159.00
# 16793981            0.75           173.00
# 16793982            0.75           658.00
# 16793983            0.50             0.00
#
# [16793984 rows x 5 columns]

# %%
pageViews = session.groupby('GA_fullVisitorId').agg({'unique_pageViews': ['mean', 'median']}).reset_index()

# rename cols
pageViews.columns = [' '.join(col).strip() for col in pageViews.columns.values]
pageViews.rename(columns={'unique_pageViews mean':'unique_pageviews_mean', 'unique_pageViews median': 'unique_pageviews_median'}, inplace=True)

# join target class
pageViews = pd.merge(pageViews, target_class, how="left", on = "GA_fullVisitorId")
pageViews
# Out:
#             GA_fullVisitorId  unique_pageviews_mean  unique_pageviews_median  \
# 0       10000049855779198375                   1.00                     1.00
# 1       10000110541771159873                   1.04                     1.00
# 2       10000113274638268984                   1.00                     1.00
# 3       10000130814584242881                  31.00                    31.00
# 4       10000151329276278902                   1.00                     1.00
# ...                      ...                    ...                      ...
# 503902   9999886779021615610                   1.00                     1.00
# 503903   9999921172181296837                   1.00                     1.00
# 503904   9999943173698081042                   1.07                     1.00
# 503905   9999987496363756221                   1.07                     1.00
# 503906   9999987504359326751                   1.00                     1.00
#
#        subscription_status
# 0           non_subscriber
# 1           non_subscriber
# 2           non_subscriber
# 3           non_subscriber
# 4           non_subscriber
# ...                    ...
# 503902      non_subscriber
# 503903      non_subscriber
# 503904      non_subscriber
# 503905      non_subscriber
# 503906      non_subscriber
#
# [503907 rows x 4 columns]

# %% [markdown]
# * Average and Median of (unique pageviews in each sessions)
#
#     * Avg. pv per session is more for subs
#     * Median pv per session is 1 for the most part as expected w/ subs median being slighlty higher

# %%
pageViews.groupby('subscription_status').unique_pageviews_mean.describe().T
# Out:
# subscription_status  non_subscriber  subscriber
# count                     402307.00   101600.00
# mean                           1.09        2.33
# std                            0.33        4.45
# min                            1.00        1.00
# 25%                            1.00        1.33
# 50%                            1.00        1.75
# 75%                            1.10        2.50
# max                           39.00      356.00

# %%
pageViews.groupby('subscription_status').unique_pageviews_median.describe().T
# Out:
# subscription_status  non_subscriber  subscriber
# count                     402307.00   101600.00
# mean                           1.03        1.88
# std                            0.32        4.43
# min                            1.00        1.00
# 25%                            1.00        1.00
# 50%                            1.00        1.00
# 75%                            1.00        2.00
# max                           39.00      356.00

# %% [markdown]
# ### Users' Time on Page in each session (avg, median)

# %%
timeOnPage = session.groupby('GA_fullVisitorId').agg({'top_per_session': ['mean', 'median']}).reset_index()

# rename cols
timeOnPage.columns = [' '.join(col).strip() for col in timeOnPage.columns.values]
timeOnPage.rename(columns={'top_per_session mean':'top_mean', 'top_per_session median': 'top_median'}, inplace=True)

# join target class
timeOnPage = pd.merge(timeOnPage, target_class, how="left", on = "GA_fullVisitorId")
timeOnPage
# Out:
#             GA_fullVisitorId  top_mean  top_median subscription_status
# 0       10000049855779198375    221.33      136.00      non_subscriber
# 1       10000110541771159873    109.48        5.50      non_subscriber
# 2       10000113274638268984    333.00      333.00      non_subscriber
# 3       10000130814584242881     23.70       23.70      non_subscriber
# 4       10000151329276278902     83.80        0.00      non_subscriber
# ...                      ...       ...         ...                 ...
# 503902   9999886779021615610     73.00       65.00      non_subscriber
# 503903   9999921172181296837     79.11       13.00      non_subscriber
# 503904   9999943173698081042    170.60       22.00      non_subscriber
# 503905   9999987496363756221    110.76       79.25      non_subscriber
# 503906   9999987504359326751    175.17      103.50      non_subscriber
#
# [503907 rows x 4 columns]

# %% [markdown]
# * Average and Median of (sum of time on page in each session)
#
#     * Both avg and median distributions for subscribers are higher than non-subs

# %%
timeOnPage.groupby('subscription_status').top_mean.describe().T
# Out:
# subscription_status  non_subscriber  subscriber
# count                     402307.00   101600.00
# mean                         114.12      210.48
# std                          181.76      321.82
# min                            0.00        0.00
# 25%                           37.90       85.53
# 50%                           71.46      149.00
# 75%                          126.07      249.65
# max                         8484.00    33240.00

# %%
timeOnPage.groupby('subscription_status').top_median.describe().T
# Out:
# subscription_status  non_subscriber  subscriber
# count                     402307.00   101600.00
# mean                          40.71       84.77
# std                           60.48      111.33
# min                            0.00        0.00
# 25%                            5.00       28.17
# 50%                           24.50       56.29
# 75%                           52.50       99.50
# max                         1518.00     4994.00

# %% [markdown]
# ### Pageviews in referral sources, country, device OS
#
# * Subs coming more from organic search.
# * Non-subs more from content aggregators

# %%
pvs_eda(df, 'GA_referralGroup') #makes sense - flipboard, newsbreak
# Out:
# subscription_status     % of non_subscriber pvs % of subscriber pvs  \
# GA_referralGroup
# organic search                            30.43               65.84
# referral                                   0.38                8.49
# direct                                     9.36                7.69
# newsletter                                 0.01                7.15
# organic social (dark)                      0.80                4.82
# organic social (forbes)                    0.09                3.11
# content aggregators                       58.89                2.80
# paid search                                0.03                0.07
# paid display                               0.00                0.02
# paid web                                   0.00                0.01
# fbia                                       0.00                0.00
# paid social (dark)                         0.00                0.00
# paid social (forbes)                       0.00                0.00
#
# subscription_status      non_subscriber_rank  subscriber_rank
# GA_referralGroup
# organic search                             2                1
# referral                                   5                2
# direct                                     3                3
# newsletter                                 8                4
# organic social (dark)                      4                5
# organic social (forbes)                    6                6
# content aggregators                        1                7
# paid search                                7                8
# paid display                              10                9
# paid web                                   9               10
# fbia                                      12               11
# paid social (dark)                        11               12
# paid social (forbes)                      12               13

# %% [markdown]
# * Subs highest in US.
# * Non-subs presence is in other countries also

# %%
pvs_eda(df, 'GA_country').drop('(not set)').head(10)
# Out:
# subscription_status % of non_subscriber pvs % of subscriber pvs  \
# GA_country
# united states                         66.22               89.93
# japan                                  0.21                1.55
# russia                                 0.03                1.21
# canada                                11.54                1.12
# united kingdom                         6.04                1.04
# australia                              3.36                0.50
# india                                  1.25                0.38
# singapore                              1.46                0.21
# mexico                                 0.24                0.16
# germany                                0.53                0.16
#
# subscription_status  non_subscriber_rank  subscriber_rank
# GA_country
# united states                          1                1
# japan                                 23                2
# russia                                61                3
# canada                                 2                4
# united kingdom                         3                5
# australia                              4                6
# india                                  6                8
# singapore                              5                9
# mexico                                20               10
# germany                                8               11

# %% [markdown]
# * Subs pvs highest from desktop
# * Non-subs pvs highest from phone

# %%
pvs_eda(df, 'deviceOS') #content aggre is an app plus we filters for articles
# Out:
# subscription_status % of non_subscriber pvs % of subscriber pvs  \
# deviceOS
# windows                                0.03               44.25
# macintosh                              0.23               39.31
# ios                                   56.58                8.25
# android                               43.14                7.70
# other                                  0.02                0.50
#
# subscription_status  non_subscriber_rank  subscriber_rank
# deviceOS
# windows                                4                1
# macintosh                              3                2
# ios                                    1                3
# android                                2                4
# other                                  5                5

# %% [markdown]
# ### Pageviews in various content categories
# * Content categories = IAB Tier 1, Tier 2, PC (shortlisted), PS (shortlisted)

# %%
content = df.copy()

# extract the start of natid string
content["natid_start"] = content.GA_cmsNaturalId.str.split("/").str[0]

print("Shape before: ", content.shape)

# keep only blogs, slides, magazine
content = content[(content['natid_start'].str.contains('blogandpostid')) | (content['natid_start'].str.contains('blogandslideid')) | (content['natid_start'].str.contains('magazine'))]

print("Shape after: ", content.shape)

# get month-year
content.GA_date = pd.to_datetime(content.GA_date)
content["mon_year"] = content['GA_date'].dt.to_period('M')
# Out:
# Shape before:  (25566117, 25)
# Shape after:  (22023999, 25)

# %%
cat = content.copy()
cat.isna().sum()
# Out:
# piano_id                    15711356
# GA_fullVisitorId                   0
# GA_visitStartTime                  0
# GA_date                            0
# GA_pagePath                        0
# GA_dfpNewZone                 316792
# GA_visitNumber                     0
# GA_pageViews                       0
# GA_scrollDepth               1666615
# timeOnPage                   1367773
# GA_cmsNaturalId                    0
# title                          68595
# publish_date                   68595
# GA_deviceOperatingSystem           0
# GA_deviceCategory                  0
# GA_deviceBrowser                   0
# GA_country                         0
# GA_referralGroup                   0
# GA_primaryChannel                  0
# GA_primarySection                  0
# tier1                        6214922
# tier2                        7273897
# subscription_status                0
# deviceOS                           0
# natid_start                        0
# mon_year                           0
# dtype: int64

# %%
print("Before - unique PC: ", len(cat.GA_primaryChannel.unique()))
print("Before - unique PS: ", len(cat.GA_primarySection.unique()), "\n")

shortlisted_channel = joblib.load("pri_channel_shortlisted.pkl")
shortlisted_section = joblib.load("pri_section_shortlisted.pkl")

# primary channel
cat["GA_primaryChannel"] = np.where(cat["GA_primaryChannel"].isin(shortlisted_channel), 
                                    cat["GA_primaryChannel"], "other")

# primary section 
cat["GA_primarySection"] = np.where(cat["GA_primarySection"].isin(shortlisted_section), 
                                    cat["GA_primarySection"], "other")

print("After shortlisting - unique PC: ", len(cat.GA_primaryChannel.unique()))
print("After shortlisting - unique PS: ", len(cat.GA_primarySection.unique()), "\n")

# fillna with 0
cat.timeOnPage = cat.timeOnPage.fillna(0)

# replace empty and NULL with "none"
cat.tier1 = cat.tier1.replace(r'^\s*$', "none", regex=True)
cat.tier1 = cat.tier1.fillna("none")

# replace empty and NULL with "none"
cat.tier2 = cat.tier2.replace(r'^\s*$', "none", regex=True)
cat.tier2 = cat.tier2.fillna("none")

print("Unique all T1s: ", len(cat.tier1.unique()))  
print("Unique all T2s: ", len(cat.tier1.unique()))
# Out:
# Before - unique PC:  35
# Before - unique PS:  159
#
# After shortlisting - unique PC:  24
# After shortlisting - unique PS:  51
#
# Unique all T1s:  31
# Unique all T2s:  31

# %%
cat.shape
# Out:
# (22023999, 26)

# %% [markdown]
# * Pageviews - Tier 1
#
#     * Subs more likely to read
#         * Busi & Fin, Personal Fin, Careers, Medical Health
#     * Non-subs more likely to read
#         * Busi & Fin, Video Gaming, Science, News & Politics

# %%
pvs_eda(cat, 'tier1', drop_cols=True)
# Out:
# subscription_status      % of non_subscriber pvs % of subscriber pvs  \
# tier1
# Business and Finance                       17.17               30.98
# Personal Finance                           15.07               10.53
# News and Politics                          11.77               10.41
# Technology & Computing                     14.38                8.75
# Medical Health                              5.77                7.22
# Video Gaming                               16.13                3.84
# Travel                                      2.16                3.08
# Careers                                     1.19                2.42
# Sports                                      1.99                2.18
# Food & Drink                                0.84                2.16
# Shopping                                    1.05                2.13
# Style & Fashion                             0.87                2.07
# Automotive                                  1.42                1.78
# Education                                   0.72                1.76
# Real Estate                                 0.73                1.43
# Television                                  1.64                1.40
# Movies                                      1.14                1.28
# Events and Attractions                      0.49                1.17
# Science                                     1.82                1.13
# Healthy Living                              0.49                0.89
# Music and Audio                             0.74                0.76
# Home & Garden                               0.75                0.72
# Family and Relationships                    0.23                0.49
# Pop Culture                                 0.35                0.44
# Hobbies & Interests                         0.39                0.33
# Books and Literature                        0.12                0.23
# Fine Art                                    0.17                0.17
# Pets                                        0.19                0.15
# Content Channel                             0.18                0.06
# Religion & Spirituality                     0.03                0.04
#
# subscription_status       non_subscriber_rank  subscriber_rank
# tier1
# Business and Finance                        1                1
# Personal Finance                            3                2
# News and Politics                           5                3
# Technology & Computing                      4                4
# Medical Health                              6                5
# Video Gaming                                2                6
# Travel                                      7                7
# Careers                                    12                8
# Sports                                      8                9
# Food & Drink                               16               10
# Shopping                                   14               11
# Style & Fashion                            15               12
# Automotive                                 11               13
# Education                                  20               14
# Real Estate                                19               15
# Television                                 10               16
# Movies                                     13               17
# Events and Attractions                     22               18
# Science                                     9               19
# Healthy Living                             21               20
# Music and Audio                            18               21
# Home & Garden                              17               22
# Family and Relationships                   25               23
# Pop Culture                                24               24
# Hobbies & Interests                        23               25
# Books and Literature                       29               26
# Fine Art                                   28               27
# Pets                                       26               28
# Content Channel                            27               29
# Religion & Spirituality                    30               30

# %% [markdown]
# * Pageviews - Tier 2
#
#     * Subs more likely to read
#         * Busi, Industries, Economy, Diseases and Conditions
#     * Non-subs more likely to read
#         * Economy, Games, Consumer Electronics, Computing, Politics

# %%
pvs_eda(cat, 'tier2', drop_cols=True).head(20)
# Out:
# subscription_status     % of non_subscriber pvs % of subscriber pvs  \
# tier2
# Business                                   4.51               18.31
# Industries                                 4.03                8.43
# Economy                                    9.57                6.27
# Computing                                  8.17                6.20
# Politics                                   7.62                6.16
# Diseases and Conditions                    4.04                5.54
# Personal Investing                         5.75                5.04
# Personal Debt                              6.38                2.14
# Video Game Genres                          6.41                1.95
# Travel Type                                1.14                1.93
# Law                                        1.78                1.77
# Vaccines                                   1.34                1.71
# Consumer Electronics                       6.72                1.62
# PC Games                                   8.71                1.36
# Artificial Intelligence                    0.21                1.19
# Personal Taxes                             0.75                1.15
# Auto Type                                  0.89                1.11
# Job Search                                 0.62                1.03
# Remote Working                             0.25                0.88
# College Education                          0.36                0.87
#
# subscription_status      non_subscriber_rank  subscriber_rank
# tier2
# Business                                   9                1
# Industries                                11                2
# Economy                                    1                3
# Computing                                  3                4
# Politics                                   4                5
# Diseases and Conditions                   10                6
# Personal Investing                         8                7
# Personal Debt                              7                8
# Video Game Genres                          6                9
# Travel Type                               17               10
# Law                                       12               11
# Vaccines                                  14               12
# Consumer Electronics                       5               13
# PC Games                                   2               14
# Artificial Intelligence                   45               15
# Personal Taxes                            21               16
# Auto Type                                 18               17
# Job Search                                22               18
# Remote Working                            41               19
# College Education                         29               20

# %% [markdown]
# * Pageviews - Primary Channel
#
#     * Subs more likely to read
#         * Busi, leadership, real estate	, small business, lifestyle??
#     * Non-subs more likely to read
#         * innovation, money, Consumer

# %%
pvs_eda(cat, 'GA_primaryChannel', drop_cols=True).head(20)
# Out:
# subscription_status % of non_subscriber pvs % of subscriber pvs  \
# GA_primaryChannel
# business                              16.88               22.37
# leadership                             8.36               22.26
# innovation                            37.99               19.77
# money                                 24.29               16.33
# lifestyle                              6.02                8.37
# small business                         0.95                4.00
# billionaires                           0.84                1.98
# real estate                            0.26                0.93
# consumer                               1.23                0.80
# shopping                               0.56                0.75
# asia                                   0.76                0.56
# entrepreneurs                          0.12                0.49
# tech                                   0.65                0.42
# industry                               0.64                0.30
# investing                              0.28                0.28
# newsletters                            0.05                0.17
# opinion                                0.06                0.09
# under 30                               0.01                0.06
# lists                                  0.02                0.04
# video                                  0.00                0.03
#
# subscription_status  non_subscriber_rank  subscriber_rank
# GA_primaryChannel
# business                               3                1
# leadership                             4                2
# innovation                             1                3
# money                                  2                4
# lifestyle                              5                5
# small business                         7                6
# billionaires                           8                7
# real estate                           14                8
# consumer                               6                9
# shopping                              12               10
# asia                                   9               11
# entrepreneurs                         15               12
# tech                                  10               13
# industry                              11               14
# investing                             13               15
# newsletters                           18               16
# opinion                               16               17
# under 30                              20               18
# lists                                 19               19
# video                                 21               20

# %% [markdown]
# * Pageviews - Primary Section
#
#     * Subs more likely to read
#         * careers, forbeswomen, leadership strategy, entrepreneurs, travel??
#     * Non-subs more likely to read
#         * games, crypto & blockchain, consumer tech

# %%
pvs_eda(cat, 'GA_primarySection', drop_cols=True).head(20)
# Out:
# subscription_status       % of non_subscriber pvs % of subscriber pvs  \
# GA_primarySection
# careers                                      2.50                6.56
# leadership strategy                          2.67                5.90
# games                                       17.87                5.80
# travel                                       2.93                4.74
# markets                                      3.85                4.65
# forbeswomen                                  1.34                4.59
# personal finance                             8.95                4.21
# hollywood & entertainment                    2.95                3.98
# crypto & blockchain                          9.32                3.88
# entrepreneurs                                1.30                3.85
# investing                                    2.66                3.33
# retail                                       0.65                3.22
# consumer tech                               12.25                3.12
# cmo network                                  0.33                3.01
# sportsmoney                                  2.45                2.34
# taxes                                        0.84                2.20
# healthcare                                   2.37                2.18
# enterprise tech                              0.38                2.14
# transportation                               0.76                1.78
# food & drink                                 0.30                1.74
#
# subscription_status        non_subscriber_rank  subscriber_rank
# GA_primarySection
# careers                                     13                1
# leadership strategy                         11                2
# games                                        1                3
# travel                                       9                4
# markets                                      6                5
# forbeswomen                                 18                6
# personal finance                             4                7
# hollywood & entertainment                    8                8
# crypto & blockchain                          3                9
# entrepreneurs                               19               10
# investing                                   12               11
# retail                                      25               12
# consumer tech                                2               13
# cmo network                                 33               14
# sportsmoney                                 14               15
# taxes                                       22               16
# healthcare                                  15               17
# enterprise tech                             32               18
# transportation                              24               19
# food & drink                                35               20

# %% [markdown]
# ### Avg. TOP in various content categories
# * Content categories = IAB Tier 1, Tier 2

# %%
t1 = cat.pivot_table(index=['GA_fullVisitorId'], 
                     columns='tier1',
                     values=['timeOnPage', 'GA_pageViews'], 
                     aggfunc='sum', 
                     fill_value=0).reset_index()
# set aside fvids
fvids = list(t1.GA_fullVisitorId)

# calc avg. top
t1_top = t1["timeOnPage"]/t1["GA_pageViews"]
t1_top = t1_top.fillna(0)

t1_top["GA_fullVisitorId"] = fvids
t1_top = pd.merge(t1_top, target_class, how="left", on="GA_fullVisitorId")

# %% [markdown]
# * Average time on page - Tier 1
#
#     * Subs spending more time on
#         * Busi & Fin, Personal Fin, News & Politics, Careers
#     * Non-subs spending more time on
#         * Video Gaming

# %%
top_eda(t1_top).rename(columns={'non_subscriber': 'non_subscriber avg. top', 'subscriber': 'subscriber avg. top'})
# Out:
# subscription_status       non_subscriber avg. top  subscriber avg. top  \
# Business and Finance                        46.65               129.02
# Personal Finance                            43.04                83.60
# Technology & Computing                      36.14                71.38
# Medical Health                              23.09                67.43
# News and Politics                           24.71                66.41
# Careers                                     10.53                39.00
# Travel                                      13.20                37.14
# Shopping                                     8.35                32.61
# Style & Fashion                              7.42                31.28
# Sports                                      10.22                29.33
# Education                                    6.19                28.97
# Food & Drink                                 6.50                27.90
# Automotive                                  11.12                27.75
# Real Estate                                  8.12                25.86
# Events and Attractions                       5.10                24.38
# Science                                     13.09                22.71
# Television                                  13.40                22.22
# Healthy Living                               5.19                20.69
# Home & Garden                                8.46                18.86
# Video Gaming                                26.39                15.25
# Family and Relationships                     3.12                14.66
# Movies                                       9.25                14.18
# Music and Audio                              5.23                13.86
# Pop Culture                                  4.25                12.47
# Hobbies & Interests                          5.09                10.13
# Books and Literature                         2.00                 7.89
# Fine Art                                     2.69                 5.53
# Pets                                         2.34                 4.89
# Content Channel                              2.32                 3.17
# Religion & Spirituality                      0.54                 1.92
#
# subscription_status       non_subscriber_rank  subscriber_rank
# Business and Finance                        1                1
# Personal Finance                            2                2
# Technology & Computing                      3                3
# Medical Health                              6                4
# News and Politics                           5                5
# Careers                                    11                6
# Travel                                      8                7
# Shopping                                   15                8
# Style & Fashion                            17                9
# Sports                                     12               10
# Education                                  19               11
# Food & Drink                               18               12
# Automotive                                 10               13
# Real Estate                                16               14
# Events and Attractions                     22               15
# Science                                     9               16
# Television                                  7               17
# Healthy Living                             21               18
# Home & Garden                              14               19
# Video Gaming                                4               20
# Family and Relationships                   25               21
# Movies                                     13               22
# Music and Audio                            20               23
# Pop Culture                                24               24
# Hobbies & Interests                        23               25
# Books and Literature                       29               26
# Fine Art                                   26               27
# Pets                                       27               28
# Content Channel                            28               29
# Religion & Spirituality                    30               30

# %% [markdown]
# * Average time on page - Tier 2
#
#     * Subs spending more time on
#         * Business, Industries
#     * Non-subs spending more time on
#         * Computing, Economy

# %%
t2 = cat.pivot_table(index=['GA_fullVisitorId'], 
                     columns='tier2',
                     values=['timeOnPage', 'GA_pageViews'], 
                     aggfunc='sum', 
                     fill_value=0).reset_index()
# set aside fvids
fvids = list(t2.GA_fullVisitorId)

# calc avg. top
t2_top = t2["timeOnPage"]/t2["GA_pageViews"]
t2_top = t2_top.fillna(0)

t2_top["GA_fullVisitorId"] = fvids
t2_top = pd.merge(t2_top, target_class, how="left", on="GA_fullVisitorId")

top_eda(t2_top).rename(columns={'non_subscriber': 'non_subscriber avg. top', 'subscriber': 'subscriber avg. top'}).head(15)
# Out:
# subscription_status      non_subscriber avg. top  subscriber avg. top  \
# Business                                   25.95               105.75
# Industries                                 22.68                81.20
# Computing                                  29.96                59.54
# Economy                                    26.22                59.38
# Personal Investing                         22.06                56.94
# Diseases and Conditions                    15.91                56.39
# Politics                                   16.88                43.18
# Law                                        10.89                27.50
# Personal Debt                              21.21                26.79
# Travel Type                                 8.37                26.29
# Vaccines                                   10.94                25.93
# Consumer Electronics                       20.77                25.76
# Job Search                                  6.30                22.22
# Personal Taxes                              7.84                19.31
# Remote Working                              2.92                19.19
#
# subscription_status      non_subscriber_rank  subscriber_rank
# Business                                   3                1
# Industries                                 4                2
# Computing                                  1                3
# Economy                                    2                4
# Personal Investing                         5                5
# Diseases and Conditions                   10                6
# Politics                                   9                7
# Law                                       13                8
# Personal Debt                              6                9
# Travel Type                               16               10
# Vaccines                                  12               11
# Consumer Electronics                       7               12
# Job Search                                23               13
# Personal Taxes                            17               14
# Remote Working                            41               15

# %% [markdown]
# ### Avg. article views in each month

# %%
user_per_mon = pd.DataFrame(content.groupby(['GA_fullVisitorId', 'subscription_status', 'mon_year']).GA_cmsNaturalId.count()).reset_index().rename(columns=
                                                                                                                                                   {'GA_cmsNaturalId':'total_article_views'})
user_per_mon
# Out:
#              GA_fullVisitorId subscription_status mon_year  \
# 0        10000049855779198375      non_subscriber  2021-10
# 1        10000110541771159873      non_subscriber  2021-07
# 2        10000110541771159873      non_subscriber  2021-08
# 3        10000110541771159873      non_subscriber  2021-09
# 4        10000110541771159873      non_subscriber  2021-10
# ...                       ...                 ...      ...
# 2874097   9999987496363756221      non_subscriber  2021-04
# 2874098   9999987496363756221      non_subscriber  2021-08
# 2874099   9999987496363756221      non_subscriber  2021-09
# 2874100   9999987496363756221      non_subscriber  2021-10
# 2874101   9999987504359326751      non_subscriber  2021-10
#
#          total_article_views
# 0                          6
# 1                          6
# 2                         14
# 3                          3
# 4                          7
# ...                      ...
# 2874097                    1
# 2874098                    4
# 2874099                    2
# 2874100                    6
# 2874101                    7
#
# [2874102 rows x 4 columns]

# %%
per_mon =  pd.DataFrame(user_per_mon.groupby(['GA_fullVisitorId', 'subscription_status']).total_article_views.mean()).reset_index() 

per_mon.GA_cmsNaturalId = per_mon.total_article_views.round() 
per_mon
# Out:
#             GA_fullVisitorId subscription_status  total_article_views
# 0       10000049855779198375      non_subscriber                 6.00
# 1       10000110541771159873      non_subscriber                 6.80
# 2       10000113274638268984      non_subscriber                 6.00
# 3       10000130814584242881      non_subscriber                10.00
# 4       10000151329276278902      non_subscriber                 5.00
# ...                      ...                 ...                  ...
# 496349   9999886779021615610      non_subscriber                 3.33
# 496350   9999921172181296837      non_subscriber                 2.75
# 496351   9999943173698081042      non_subscriber                 4.33
# 496352   9999987496363756221      non_subscriber                 3.91
# 496353   9999987504359326751      non_subscriber                 7.00
#
# [496354 rows x 3 columns]

# %% [markdown]
# * Avg(actual articles per month)
#     * Subs on whole have been reading more articles in a month than non-subs

# %%
per_mon.groupby('subscription_status').total_article_views.describe().T
# Out:
# subscription_status  non_subscriber  subscriber
# count                     402307.00    94047.00
# mean                           5.04       13.69
# std                            3.62       30.80
# min                            1.29        1.00
# 25%                            3.00        4.50
# 50%                            4.33        8.00
# 75%                            6.00       15.00
# max                          297.50     3740.00

# %%
# example non-subs
user_per_mon[user_per_mon.GA_fullVisitorId=='10000058813304965608']
# Out:
#         GA_fullVisitorId subscription_status mon_year  GA_cmsNaturalId
# 0   10000058813304965608      non_subscriber  2020-02                6
# 1   10000058813304965608      non_subscriber  2020-03               14
# 2   10000058813304965608      non_subscriber  2020-04               13
# 3   10000058813304965608      non_subscriber  2020-05               27
# 4   10000058813304965608      non_subscriber  2020-06               15
# 5   10000058813304965608      non_subscriber  2020-07                9
# 6   10000058813304965608      non_subscriber  2020-08                1
# 7   10000058813304965608      non_subscriber  2020-09               13
# 8   10000058813304965608      non_subscriber  2020-10               23
# 9   10000058813304965608      non_subscriber  2020-11               13
# 10  10000058813304965608      non_subscriber  2020-12                7
# 11  10000058813304965608      non_subscriber  2021-01               11
# 12  10000058813304965608      non_subscriber  2021-02               15
# 13  10000058813304965608      non_subscriber  2021-03                5
# 14  10000058813304965608      non_subscriber  2021-04                6
# 15  10000058813304965608      non_subscriber  2021-05                4
# 16  10000058813304965608      non_subscriber  2021-06                3
# 17  10000058813304965608      non_subscriber  2021-07                9
# 18  10000058813304965608      non_subscriber  2021-08                4
# 19  10000058813304965608      non_subscriber  2021-09                1
# 20  10000058813304965608      non_subscriber  2021-10                1

# %%
# example subs
user_per_mon[user_per_mon.GA_fullVisitorId=='3857395123229566996']
# Out:
#            GA_fullVisitorId subscription_status mon_year  GA_cmsNaturalId
# 491055  3857395123229566996          subscriber  2020-03                2
# 491056  3857395123229566996          subscriber  2020-04               10
# 491057  3857395123229566996          subscriber  2020-05                5
# 491058  3857395123229566996          subscriber  2020-06               12
# 491059  3857395123229566996          subscriber  2020-07                8
# 491060  3857395123229566996          subscriber  2020-08                9
# 491061  3857395123229566996          subscriber  2020-09                1
# 491062  3857395123229566996          subscriber  2020-10               10
# 491063  3857395123229566996          subscriber  2020-11                8
# 491064  3857395123229566996          subscriber  2020-12               17
# 491065  3857395123229566996          subscriber  2021-01                4
# 491066  3857395123229566996          subscriber  2021-02               10
# 491067  3857395123229566996          subscriber  2021-03               10

# %%
# example subs
user_per_mon[user_per_mon.GA_fullVisitorId=='5277846215104667271']
# Out:
#            GA_fullVisitorId subscription_status mon_year  GA_cmsNaturalId
# 627088  5277846215104667271          subscriber  2020-03                3
# 627089  5277846215104667271          subscriber  2020-04               38
# 627090  5277846215104667271          subscriber  2020-05               34
# 627091  5277846215104667271          subscriber  2020-06               96
# 627092  5277846215104667271          subscriber  2020-07               38
# 627093  5277846215104667271          subscriber  2020-08               69
# 627094  5277846215104667271          subscriber  2020-09               42
# 627095  5277846215104667271          subscriber  2020-10               55
# 627096  5277846215104667271          subscriber  2020-11               73
# 627097  5277846215104667271          subscriber  2020-12              109
# 627098  5277846215104667271          subscriber  2021-01              145
# 627099  5277846215104667271          subscriber  2021-02               48
# 627100  5277846215104667271          subscriber  2021-03              150
# 627101  5277846215104667271          subscriber  2021-04               78
# 627102  5277846215104667271          subscriber  2021-05               81
# 627103  5277846215104667271          subscriber  2021-06               10
# 627104  5277846215104667271          subscriber  2021-07               11

# %%
# next steps - data settings: no article limit data - make 1 data. ga_date greater than jan-2021
# send tables - fullvid for subs + nonsubs - 1 single EDA file
# feature selection amd model v1 before dec 9

# %%
# tried to question data - 2 ques but this may be inline with expectation. review?

# %%
# finalize preliminary EDA

# %%
# joining with C-levels for curiosity

start_time = time.time()

sql = """
    SELECT 
        *
      FROM (
        SELECT 
            DISTINCT *,
            RANK() OVER (PARTITION BY GA_fullVisitorId ORDER BY date DESC) AS mostrecent,
        FROM
            `api-project-901373404215.lookalike.zoom_info_c_level`
          )
      WHERE 
          mostrecent = 1
"""

clevels = (
    bqclient.query(sql)
    .result()
    .to_dataframe(bqstorage_client=bqstorageclient)
) 

print("--- %s seconds ---" % (time.time() - start_time)) #12.45

# %%
clevels
