# %%
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.2f' % x)
import numpy as np
from google.cloud import bigquery
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style('darkgrid')
import joblib
import warnings
warnings.filterwarnings('ignore') 
import re

bq_client = bigquery.Client()

# %%
import google.auth
from google.cloud import bigquery
from google.cloud import bigquery_storage
import time

bqclient = bigquery.Client()
bqstorageclient = bigquery_storage.BigQueryReadClient()

# %%
def pvs_eda(input_df, cat_col_name, drop_cols=False):
    
    # pivot
    df_cat = pd.pivot_table(
        input_df, 
        values='GA_pageViews',
        columns= cat_col_name,
        index='subscription_status',
        aggfunc='sum')\
        .reset_index()
    
    # drop none and other cols
    if drop_cols==True:
        
        if 'none' in list(df_cat.columns):
            df_cat.drop('none', axis=1, inplace=True)
        
        if 'other' in list(df_cat.columns):
            df_cat.drop('other', axis=1, inplace=True)

    
    # percentage calc below
    df_cat = df_cat.fillna(0)
    df_cat = df_cat.T
    
    new_header = df_cat.iloc[0] # grab the first row for the header
    df_cat = df_cat[1:] # take the data minus the header row
    df_cat.columns = new_header
  
    df_cat['% of non_subscriber pvs'] = (df_cat['non_subscriber'] / df_cat['non_subscriber'].sum()) * 100
    df_cat['% of subscriber pvs'] = (df_cat['subscriber'] / df_cat['subscriber'].sum()) * 100
    
    df_cat.drop(['non_subscriber', 'subscriber'], axis=1, inplace=True)

    df_cat['non_subscriber_rank'] = df_cat['% of non_subscriber pvs'].rank(ascending=False).astype(int)
    df_cat['subscriber_rank'] = df_cat['% of subscriber pvs'].rank(ascending=False).astype(int)

    df_cat = df_cat.sort_values('subscriber_rank')
    
    return df_cat

# %%
def top_eda(df):
    '''
    Prep df for eda
    '''
    # remove column = "none" i.e. Tier 1/Tier2/PC/PS was not available
    df.drop("none", axis=1, inplace=True)
    
    # group all subscribers, calculate mean of their (avg. time on page) for each category. Same for Non-subscribers
    df = df.groupby('subscription_status').mean().T
    
    # assign rank
    df['non_subscriber_rank'] = df['non_subscriber'].rank(ascending=False).astype(int)
    df['subscriber_rank'] = df['subscriber'].rank(ascending=False).astype(int)
    df = df.sort_values('subscriber_rank')

    return df

# %% [markdown]
# ## DATA

# %%
start_time = time.time()

query_string = """
  SELECT
       *
    FROM
        `api-project-901373404215.skt.subscriber_ga_data`
"""

subs_data = (
    bqclient.query(query_string)
    .result()
    .to_dataframe(bqstorage_client=bqstorageclient)
) 

print("--- %s seconds ---" % (time.time() - start_time))

subs_data["subscription_status"] = "subscriber"

# drop unnecessary col & rename
subs_data.drop(['user_id_uid', 'resource_id_rid'], axis=1, inplace=True)
subs_data.rename(columns={'ga_pianoId': 'piano_id'}, inplace=True)

# drop dups
# subs_data.drop_duplicates(keep='first', inplace=True)

print(subs_data.shape)
print("Unique unlimited subscribers: ", len(subs_data.piano_id.unique()))
print("Unique unlimited fullvids: ", len(subs_data.GA_fullVisitorId.unique()), "\n")
print("Duplicates?: ", subs_data.duplicated().any())

subs_data.head()
# Out:
# --- 23.603087186813354 seconds ---
# (9746613, 23)
# Unique unlimited subscribers:  42678
# Unique unlimited fullvids:  101600
#
# Duplicates?:  True
#           piano_id     GA_fullVisitorId  GA_visitStartTime     GA_date  \
# 0  pni0hkm7oqjzww7  5648315289347757915         1633454424  2021-10-05
# 1  pni49gmy7qnaeqe  7460490544181184665         1611958424  2021-01-29
# 2  pniohazwsqkmkqb  3996879997278966106         1612361085  2021-02-03
# 3  pniptkdboqj82qy  3206243803054980323         1623795177  2021-06-15
# 4  pniirhrfiqzfn7f  4623187229507344716         1633469388  2021-10-05
#
#                                          GA_pagePath  \
# 0  /sites/robinryan/2021/10/05/add-a-linkedin-bac...
# 1  /sites/lizryan/2017/05/15/how-to-handle-a-bait...
# 2  /sites/jackkelly/2021/02/02/amazons-new-massiv...
# 3  /sites/williamarruda/2021/06/13/5-red-flags-to...
# 4  /sites/davidsturt/2018/03/08/10-shocking-workp...
#
#                      GA_dfpNewZone  GA_visitNumber  GA_pageViews  \
# 0  article/standard/subscriber/alx              44             1
# 1  article/standard/subscriber/alx               1             1
# 2  article/standard/subscriber/alx              88             1
# 3  article/standard/subscriber/alx             118             1
# 4  article/standard/subscriber/alx              32             1
#
#    GA_scrollDepth  timeOnPage  ... GA_deviceOperatingSystem GA_deviceCategory  \
# 0            0.00        3.00  ...                  windows           desktop
# 1            0.75       35.00  ...                macintosh           desktop
# 2            0.75      560.00  ...                  windows           desktop
# 3            0.75       51.00  ...                  windows           desktop
# 4            1.00       25.00  ...                  windows           desktop
#
#   GA_deviceBrowser     GA_country GA_referralGroup GA_primaryChannel  \
# 0           chrome  united states   organic search        leadership
# 1           safari  united states   organic search        leadership
# 2           chrome  united states   organic search        leadership
# 3             edge  united states   organic search        leadership
# 4           chrome  united states   organic search        leadership
#
#   GA_primarySection        tier1                tier2 subscription_status
# 0           careers         None                 None          subscriber
# 1           careers         None                 None          subscriber
# 2           careers  Real Estate  Developmental Sites          subscriber
# 3           careers      Careers                 None          subscriber
# 4           careers         None                 None          subscriber
#
# [5 rows x 23 columns]

# %%
start_time = time.time()

query_string = """
  SELECT
       *
    FROM
        `api-project-901373404215.skt.nonsubscriber_ga_data`
"""

nonsubs_data = (
    bqclient.query(query_string)
    .result()
    .to_dataframe(bqstorage_client=bqstorageclient)
) 

print("--- %s seconds ---" % (time.time() - start_time))

nonsubs_data["subscription_status"] = "non_subscriber"

print("Duplicates?: ", nonsubs_data.duplicated().any())


print("---Before removing suspicious fvids---")
print(nonsubs_data.shape)
print("Unique unlimited fullvids: ", len(nonsubs_data.GA_fullVisitorId.unique()), "\n")

nonsubs_data.GA_dfpNewZone = nonsubs_data.GA_dfpNewZone.fillna('none')
suspicious_fvid = nonsubs_data[nonsubs_data.GA_dfpNewZone.str.contains('/subscriber/')].GA_fullVisitorId.unique()
print("---After removing suspicious fvids---", len(suspicious_fvid))
nonsubs_data = nonsubs_data[~nonsubs_data.GA_fullVisitorId.isin(suspicious_fvid)]
print(nonsubs_data.shape)
print("Unique unlimited fullvids: ", len(nonsubs_data.GA_fullVisitorId.unique()), "\n")


nonsubs_data.head()
# Out:
# --- 13.846479177474976 seconds ---
# Duplicates?:  True
# ---Before removing suspicious fvids---
# (5014346, 23)
# Unique unlimited fullvids:  109738
#
# ---After removing suspicious fvids--- 155
# (4995517, 23)
# Unique unlimited fullvids:  109583
#   piano_id      GA_fullVisitorId  GA_visitStartTime     GA_date  \
# 0     None   4322305614776686660         1602062780  2020-10-07
# 1     None  11020952544086358612         1610486452  2021-01-12
# 2     None  17312517012768210000         1596333111  2020-08-01
# 3     None   1358346986832705004         1603433574  2020-10-23
# 4     None   7782286270075194416         1603089853  2020-10-19
#
#                                          GA_pagePath  \
# 0  /sites/gordonkelly/2020/10/06/apple-iphone-12-...
# 1  /sites/zakdoffman/2021/01/12/if-these-apps-are...
# 2  /sites/daveywinder/2020/08/01/this-samsung-sec...
# 3  /sites/gordonkelly/2020/10/22/apple-iphone-13-...
# 4  /sites/johnarcher/2020/10/18/lg-oled48cx-oled-...
#
#                            GA_dfpNewZone  GA_visitNumber  GA_pageViews  \
# 0      article/standard/default/standard             224             1
# 1  article-amp/standard/default/standard               6             1
# 2  article-amp/standard/default/standard              26             1
# 3  article-amp/standard/default/standard             103             1
# 4  article-amp/standard/default/standard             318             1
#
#    GA_scrollDepth  timeOnPage  ... GA_deviceOperatingSystem GA_deviceCategory  \
# 0            0.25       20.00  ...                  android           desktop
# 1            0.50        3.00  ...                  android            mobile
# 2            0.50       45.00  ...                  android            mobile
# 3            0.50       55.00  ...                  android            mobile
# 4            0.00        0.00  ...                  android            mobile
#
#   GA_deviceBrowser      GA_country     GA_referralGroup GA_primaryChannel  \
# 0  android webview          canada  content aggregators        innovation
# 1  android webview   united states  content aggregators        innovation
# 2  android webview   united states  content aggregators        innovation
# 3  android webview  united kingdom  content aggregators        innovation
# 4  android webview   united states  content aggregators        innovation
#
#   GA_primarySection                   tier1                 tier2  \
# 0     consumer tech  Technology & Computing  Consumer Electronics
# 1     cybersecurity  Technology & Computing  Consumer Electronics
# 2     cybersecurity  Technology & Computing  Consumer Electronics
# 3     consumer tech  Technology & Computing  Consumer Electronics
# 4     consumer tech  Technology & Computing  Consumer Electronics
#
#   subscription_status
# 0      non_subscriber
# 1      non_subscriber
# 2      non_subscriber
# 3      non_subscriber
# 4      non_subscriber
#
# [5 rows x 23 columns]

# %%
# any col names mismatch? - no

[x for x in list(subs_data.columns) if x not in list(nonsubs_data.columns)]
# Out:
# []

# %%
df = pd.concat([subs_data, nonsubs_data])

print("Shape: ", df.shape)

# fill na
df.GA_cmsNaturalId = df.GA_cmsNaturalId.fillna('None') 

# short list device OS
shortlisted_os = ["android", "ios", "macintosh", "windows"]

df["deviceOS"] = np.where(df["GA_deviceOperatingSystem"].isin(shortlisted_os), 
                          df["GA_deviceOperatingSystem"], 
                          "other")

df[['GA_fullVisitorId', 'subscription_status']].drop_duplicates(keep='first').subscription_status.value_counts()
# Out:
# Shape:  (14742130, 23)
# non_subscriber    109583
# subscriber        101600
# Name: subscription_status, dtype: int64

# %%
df.head()
# Out:
#           piano_id     GA_fullVisitorId  GA_visitStartTime     GA_date  \
# 0  pni0hkm7oqjzww7  5648315289347757915         1633454424  2021-10-05
# 1  pni49gmy7qnaeqe  7460490544181184665         1611958424  2021-01-29
# 2  pniohazwsqkmkqb  3996879997278966106         1612361085  2021-02-03
# 3  pniptkdboqj82qy  3206243803054980323         1623795177  2021-06-15
# 4  pniirhrfiqzfn7f  4623187229507344716         1633469388  2021-10-05
#
#                                          GA_pagePath  \
# 0  /sites/robinryan/2021/10/05/add-a-linkedin-bac...
# 1  /sites/lizryan/2017/05/15/how-to-handle-a-bait...
# 2  /sites/jackkelly/2021/02/02/amazons-new-massiv...
# 3  /sites/williamarruda/2021/06/13/5-red-flags-to...
# 4  /sites/davidsturt/2018/03/08/10-shocking-workp...
#
#                      GA_dfpNewZone  GA_visitNumber  GA_pageViews  \
# 0  article/standard/subscriber/alx              44             1
# 1  article/standard/subscriber/alx               1             1
# 2  article/standard/subscriber/alx              88             1
# 3  article/standard/subscriber/alx             118             1
# 4  article/standard/subscriber/alx              32             1
#
#    GA_scrollDepth  timeOnPage  ... GA_deviceCategory GA_deviceBrowser  \
# 0            0.00        3.00  ...           desktop           chrome
# 1            0.75       35.00  ...           desktop           safari
# 2            0.75      560.00  ...           desktop           chrome
# 3            0.75       51.00  ...           desktop             edge
# 4            1.00       25.00  ...           desktop           chrome
#
#       GA_country GA_referralGroup GA_primaryChannel GA_primarySection  \
# 0  united states   organic search        leadership           careers
# 1  united states   organic search        leadership           careers
# 2  united states   organic search        leadership           careers
# 3  united states   organic search        leadership           careers
# 4  united states   organic search        leadership           careers
#
#          tier1                tier2 subscription_status   deviceOS
# 0         None                 None          subscriber    windows
# 1         None                 None          subscriber  macintosh
# 2  Real Estate  Developmental Sites          subscriber    windows
# 3      Careers                 None          subscriber    windows
# 4         None                 None          subscriber    windows
#
# [5 rows x 24 columns]

# %%
target_class = df[['GA_fullVisitorId', 'subscription_status']].drop_duplicates(keep='first')

# %% [markdown]
# ### User's whole behavior
# **i.e., avg. top and sum(pvs) over whole GA history**

# %%
whole = df.groupby(['GA_fullVisitorId', 'subscription_status']).agg({'GA_pageViews': 'sum', 'timeOnPage': 'sum'}).reset_index().rename(columns={'GA_pageViews': 'sum_pvs'})
whole["avg_top"] = whole['timeOnPage']/whole['sum_pvs']

whole
# Out:
#             GA_fullVisitorId subscription_status  sum_pvs  timeOnPage  avg_top
# 0       10000058813304965608      non_subscriber      200    15870.00    79.35
# 1       10000251105399450511      non_subscriber      117    10958.00    93.66
# 2       10000610991313890343      non_subscriber       12     2076.00   173.00
# 3        1000096511026234346          subscriber       31     1904.00    61.42
# 4        1000104336364784244          subscriber       92    16635.00   180.82
# ...                      ...                 ...      ...         ...      ...
# 211178   9999629024408201784      non_subscriber        7       75.00    10.71
# 211179    999969109989075422      non_subscriber       27     3096.00   114.67
# 211180   9999757056159711694      non_subscriber      195    13977.00    71.68
# 211181   9999883233119772718      non_subscriber       11     1628.00   148.00
# 211182   9999953169198331967      non_subscriber        5      230.00    46.00
#
# [211183 rows x 5 columns]

# %% [markdown]
# * Distribution of sum(pvs)
#     * Even after limiting non-subs with >5 articles, on a whole -- subs have more pvs than non-subs (except extreme values)

# %%
whole.groupby('subscription_status').sum_pvs.describe().T
# Out:
# subscription_status  non_subscriber  subscriber
# count                     109583.00   101600.00
# mean                          45.59       95.93
# std                          483.64      616.55
# min                            5.00        1.00
# 25%                            8.00       10.00
# 50%                           15.00       24.00
# 75%                           36.00       65.00
# max                       155102.00    76285.00

# %% [markdown]
# * Distribution of avg(top)
#     * Subs spend more avg. top than non-subs on a whole

# %%
whole.groupby('subscription_status').avg_top.describe().T
# Out:
# subscription_status  non_subscriber  subscriber
# count                     109583.00   101600.00
# mean                          92.94      138.33
# std                           99.84      103.77
# min                            0.00        0.00
# 25%                           31.40       68.00
# 50%                           66.08      118.27
# 75%                          119.00      181.84
# max                         5661.83     2497.00

# %% [markdown]
# ### Users' Unique Pageviews in each session (avg, median)

# %%
# user's per pagepath GA data
page = df.groupby(['GA_fullVisitorId', 'GA_visitStartTime', 'GA_pagePath']).agg({'GA_pageViews': 'max', 'GA_scrollDepth': 'max', 'timeOnPage': 'sum'}).reset_index()

# user's per session GA data
session = page.groupby(['GA_fullVisitorId', 'GA_visitStartTime']).agg({'GA_pageViews': 'sum', 'GA_scrollDepth': 'mean', 'timeOnPage': 'mean'}).reset_index()

session.rename(columns={'GA_pageViews': 'unique_pageViews', 'timeOnPage': 'top_per_session'}, inplace=True)
session
# Out:
#              GA_fullVisitorId  GA_visitStartTime  unique_pageViews  \
# 0        10000058813304965608         1582907879                 1
# 1        10000058813304965608         1582991705                 4
# 2        10000058813304965608         1583126231                 1
# 3        10000058813304965608         1584312177                 1
# 4        10000058813304965608         1584746000                 1
# ...                       ...                ...               ...
# 7146908   9999953169198331967         1626093686                 1
# 7146909   9999953169198331967         1626266711                 1
# 7146910   9999953169198331967         1626612852                 1
# 7146911   9999953169198331967         1626697065                 1
# 7146912   9999953169198331967         1626725250                 1
#
#          GA_scrollDepth  top_per_session
# 0                  1.00             9.00
# 1                  1.00           517.00
# 2                  1.00             9.00
# 3                  1.00             4.00
# 4                  1.00             8.00
# ...                 ...              ...
# 7146908            0.00             0.00
# 7146909            0.50            49.00
# 7146910            0.50            14.00
# 7146911            0.25            10.00
# 7146912            0.50           157.00
#
# [7146913 rows x 5 columns]

# %% [markdown]
# * Average and Median of (unique pageviews in each sessions)

# %%
pageViews = session.groupby('GA_fullVisitorId').agg({'unique_pageViews': ['mean', 'median']}).reset_index()

# rename cols
pageViews.columns = [' '.join(col).strip() for col in pageViews.columns.values]
pageViews.rename(columns={'unique_pageViews mean':'unique_pageviews_mean', 'unique_pageViews median': 'unique_pageviews_median'}, inplace=True)

# join target class
pageViews = pd.merge(pageViews, target_class, how="left", on = "GA_fullVisitorId")
pageViews
# Out:
#             GA_fullVisitorId  unique_pageviews_mean  unique_pageviews_median  \
# 0       10000058813304965608                   1.14                     1.00
# 1       10000251105399450511                   1.81                     1.00
# 2       10000610991313890343                   1.00                     1.00
# 3        1000096511026234346                   3.00                     2.50
# 4        1000104336364784244                   1.67                     1.00
# ...                      ...                    ...                      ...
# 211178   9999629024408201784                   1.00                     1.00
# 211179    999969109989075422                   1.08                     1.00
# 211180   9999757056159711694                   1.16                     1.00
# 211181   9999883233119772718                   1.00                     1.00
# 211182   9999953169198331967                   1.00                     1.00
#
#        subscription_status
# 0           non_subscriber
# 1           non_subscriber
# 2           non_subscriber
# 3               subscriber
# 4               subscriber
# ...                    ...
# 211178      non_subscriber
# 211179      non_subscriber
# 211180      non_subscriber
# 211181      non_subscriber
# 211182      non_subscriber
#
# [211183 rows x 4 columns]

# %%
pageViews.groupby('subscription_status').unique_pageviews_mean.describe().T
# Out:
# subscription_status  non_subscriber  subscriber
# count                     109583.00   101600.00
# mean                           1.29        2.33
# std                            1.01        4.45
# min                            1.00        1.00
# 25%                            1.00        1.33
# 50%                            1.08        1.75
# 75%                            1.21        2.50
# max                          142.00      356.00

# %%
pageViews.groupby('subscription_status').unique_pageviews_median.describe().T
# Out:
# subscription_status  non_subscriber  subscriber
# count                     109583.00   101600.00
# mean                           1.18        1.88
# std                            0.99        4.43
# min                            1.00        1.00
# 25%                            1.00        1.00
# 50%                            1.00        1.00
# 75%                            1.00        2.00
# max                          142.00      356.00

# %% [markdown]
# ### Users' Time on Page in each session (avg, median)

# %%
timeOnPage = session.groupby('GA_fullVisitorId').agg({'timeOnPage': ['mean', 'median']}).reset_index()

# rename cols
timeOnPage.columns = [' '.join(col).strip() for col in timeOnPage.columns.values]
timeOnPage.rename(columns={'timeOnPage mean':'top_mean', 'timeOnPage median': 'top_median'}, inplace=True)

# join target class
timeOnPage = pd.merge(timeOnPage, target_class, how="left", on = "GA_fullVisitorId")
timeOnPage
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_13965/4103909902.py in <module>
# ----> 1 timeOnPage = session.groupby('GA_fullVisitorId').agg({'timeOnPage': ['mean', 'median']}).reset_index()
#       2
#       3 # rename cols
#       4 timeOnPage.columns = [' '.join(col).strip() for col in timeOnPage.columns.values]
#       5 timeOnPage.rename(columns={'timeOnPage mean':'top_mean', 'timeOnPage median': 'top_median'}, inplace=True)
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     949         func = maybe_mangle_lambdas(func)
#     950
# --> 951         result, how = self._aggregate(func, *args, **kwargs)
#     952         if how is None:
#     953             return result
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/base.py in _aggregate(self, arg, *args, **kwargs)
#     340                         raise SpecificationError("nested renamer is not supported")
#     341                     elif isinstance(obj, ABCDataFrame) and k not in obj.columns:
# --> 342                         raise KeyError(f"Column '{k}' does not exist!")
#     343
#     344                 arg = new_arg
#
# KeyError: "Column 'timeOnPage' does not exist!"

# %% [markdown]
# * Average and Median of (sum of time on page in each session)

# %%
timeOnPage.groupby('subscription_status').top_mean.describe().T
# Out:
# subscription_status  non_subscriber  subscriber
# count                     109738.00   101600.00
# mean                         110.69      210.48
# std                          184.45      321.82
# min                            0.00        0.00
# 25%                           30.78       85.53
# 50%                           64.27      149.00
# 75%                          123.67      249.65
# max                         9542.00    33240.00

# %%
timeOnPage.groupby('subscription_status').top_median.describe().T
# Out:
# subscription_status  non_subscriber  subscriber
# count                     109738.00   101600.00
# mean                          58.56      123.16
# std                          166.54      286.59
# min                            0.00        0.00
# 25%                            2.00       36.00
# 50%                           21.00       71.38
# 75%                           56.00      134.00
# max                         9542.00    33240.00

# %% [markdown]
# ### Pageviews in referral sources, country, device OS

# %%
pvs_eda(df, 'GA_referralGroup')
# Out:
# subscription_status     % of non_subscriber pvs % of subscriber pvs  \
# GA_referralGroup
# organic search                            25.84               65.84
# referral                                   1.65                8.49
# direct                                     4.30                7.69
# newsletter                                 0.64                7.15
# organic social (dark)                      4.35                4.82
# organic social (forbes)                    8.06                3.11
# content aggregators                       53.61                2.80
# paid search                                0.02                0.07
# paid display                               0.00                0.02
# paid web                                   0.01                0.01
# fbia                                       1.53                0.00
# paid social (dark)                         0.00                0.00
# paid social (forbes)                       0.00                0.00
#
# subscription_status      non_subscriber_rank  subscriber_rank
# GA_referralGroup
# organic search                             2                1
# referral                                   6                2
# direct                                     5                3
# newsletter                                 8                4
# organic social (dark)                      4                5
# organic social (forbes)                    3                6
# content aggregators                        1                7
# paid search                                9                8
# paid display                              11                9
# paid web                                  10               10
# fbia                                       7               11
# paid social (dark)                        13               12
# paid social (forbes)                      12               13

# %%
pvs_eda(df, 'GA_country').drop('(not set)').head(10)
# Out:
# subscription_status % of non_subscriber pvs % of subscriber pvs  \
# GA_country
# united states                         69.40               89.93
# japan                                  0.19                1.55
# russia                                 0.09                1.21
# canada                                 8.16                1.12
# united kingdom                         7.36                1.04
# australia                              1.95                0.50
# india                                  1.41                0.38
# singapore                              0.94                0.21
# mexico                                 0.54                0.16
# germany                                0.48                0.16
#
# subscription_status  non_subscriber_rank  subscriber_rank
# GA_country
# united states                          1                1
# japan                                 23                2
# russia                                38                3
# canada                                 2                4
# united kingdom                         3                5
# australia                              4                6
# india                                  5                8
# singapore                              6                9
# mexico                                 8               10
# germany                               10               11

# %%
pvs_eda(df, 'deviceOS')
# Out:
# subscription_status % of non_subscriber pvs % of subscriber pvs  \
# deviceOS
# windows                                5.59               44.25
# macintosh                              3.04               39.31
# ios                                   48.79                8.25
# android                               42.13                7.70
# other                                  0.45                0.50
#
# subscription_status  non_subscriber_rank  subscriber_rank
# deviceOS
# windows                                3                1
# macintosh                              4                2
# ios                                    1                3
# android                                2                4
# other                                  5                5

# %%
pvs_eda(df, 'deviceOS')
# Out:
# subscription_status % of non_subscriber pvs % of subscriber pvs  \
# deviceOS
# windows                                5.59               44.25
# macintosh                              3.04               39.31
# ios                                   48.79                8.25
# android                               42.13                7.70
# other                                  0.45                0.50
#
# subscription_status  non_subscriber_rank  subscriber_rank
# deviceOS
# windows                                3                1
# macintosh                              4                2
# ios                                    1                3
# android                                2                4
# other                                  5                5

# %% [markdown]
# ### Pageviews in various content categories
# * Content categories = IAB Tier 1, Tier 2, PC, PS

# %%
content = df.copy()

# extract the start of natid string
content["natid_start"] = content.GA_cmsNaturalId.str.split("/").str[0]

print("Shape before: ", content.shape)

# keep only blogs, slides, magazine
content = content[(content['natid_start'].str.contains('blogandpostid')) | (content['natid_start'].str.contains('blogandslideid')) | (content['natid_start'].str.contains('magazine'))]

print("Shape after: ", content.shape)

# get month-year
content.GA_date = pd.to_datetime(content.GA_date)
content["mon_year"] = content['GA_date'].dt.to_period('M')
# Out:
# Shape before:  (14760959, 25)
# Shape after:  (11055442, 25)

# %%
cat = content.copy()
cat.isna().sum()
# Out:
# piano_id                    4742799
# GA_fullVisitorId                  0
# GA_visitStartTime                 0
# GA_date                           0
# GA_pagePath                       0
# GA_dfpNewZone                814879
# GA_visitNumber                    0
# GA_pageViews                      0
# GA_scrollDepth              1513107
# timeOnPage                   405121
# GA_cmsNaturalId                   0
# title                         56501
# publish_date                  56501
# GA_deviceOperatingSystem          0
# GA_deviceCategory                 0
# GA_deviceBrowser                  0
# GA_country                        0
# GA_referralGroup                  0
# GA_primaryChannel                 0
# GA_primarySection                 0
# tier1                       2575048
# tier2                       3221833
# subscription_status               0
# deviceOS                          0
# natid_start                       0
# mon_year                          0
# dtype: int64

# %%
print("Before - unique PC: ", len(cat.GA_primaryChannel.unique()))
print("Before - unique PS: ", len(cat.GA_primarySection.unique()), "\n")

shortlisted_channel = joblib.load("pri_channel_shortlisted.pkl")
shortlisted_section = joblib.load("pri_section_shortlisted.pkl")

# primary channel
cat["GA_primaryChannel"] = np.where(cat["GA_primaryChannel"].isin(shortlisted_channel), 
                                    cat["GA_primaryChannel"], "other")

# primary section 
cat["GA_primarySection"] = np.where(cat["GA_primarySection"].isin(shortlisted_section), 
                                    cat["GA_primarySection"], "other")

print("After shortlisting - unique PC: ", len(cat.GA_primaryChannel.unique()))
print("After shortlisting - unique PS: ", len(cat.GA_primarySection.unique()), "\n")

# fillna with 0
cat.timeOnPage = cat.timeOnPage.fillna(0)

# replace empty and NULL with "none"
cat.tier1 = cat.tier1.replace(r'^\s*$', "none", regex=True)
cat.tier1 = cat.tier1.fillna("none")

# replace empty and NULL with "none"
cat.tier2 = cat.tier2.replace(r'^\s*$', "none", regex=True)
cat.tier2 = cat.tier2.fillna("none")

print("Unique all T1s: ", len(cat.tier1.unique()))  
print("Unique all T2s: ", len(cat.tier1.unique()))
# Out:
# Before - unique PC:  35
# Before - unique PS:  156
#
# After shortlisting - unique PC:  24
# After shortlisting - unique PS:  51
#
# Unique all T1s:  31
# Unique all T2s:  31

# %% [markdown]
# * Pageviews - Tier 1

# %%
pvs_eda(cat, 'tier1', drop_cols=True)
# Out:
# subscription_status      % of non_subscriber pvs % of subscriber pvs  \
# tier1
# Business and Finance                       17.19               30.98
# Personal Finance                           12.53               10.53
# News and Politics                          28.48               10.41
# Technology & Computing                      9.85                8.75
# Medical Health                              7.20                7.22
# Video Gaming                                7.34                3.84
# Travel                                      2.16                3.08
# Careers                                     1.05                2.42
# Sports                                      1.83                2.18
# Food & Drink                                0.74                2.16
# Shopping                                    0.97                2.13
# Style & Fashion                             0.75                2.07
# Automotive                                  1.13                1.78
# Education                                   0.86                1.76
# Real Estate                                 0.73                1.43
# Television                                  1.22                1.40
# Movies                                      0.81                1.28
# Events and Attractions                      0.56                1.17
# Science                                     1.36                1.13
# Healthy Living                              0.50                0.89
# Music and Audio                             0.71                0.76
# Home & Garden                               0.51                0.72
# Family and Relationships                    0.29                0.49
# Pop Culture                                 0.41                0.44
# Hobbies & Interests                         0.33                0.33
# Books and Literature                        0.13                0.23
# Fine Art                                    0.12                0.17
# Pets                                        0.08                0.15
# Content Channel                             0.13                0.06
# Religion & Spirituality                     0.03                0.04
#
# subscription_status       non_subscriber_rank  subscriber_rank
# tier1
# Business and Finance                        2                1
# Personal Finance                            3                2
# News and Politics                           1                3
# Technology & Computing                      4                4
# Medical Health                              6                5
# Video Gaming                                5                6
# Travel                                      7                7
# Careers                                    12                8
# Sports                                      8                9
# Food & Drink                               17               10
# Shopping                                   13               11
# Style & Fashion                            16               12
# Automotive                                 11               13
# Education                                  14               14
# Real Estate                                18               15
# Television                                 10               16
# Movies                                     15               17
# Events and Attractions                     20               18
# Science                                     9               19
# Healthy Living                             22               20
# Music and Audio                            19               21
# Home & Garden                              21               22
# Family and Relationships                   25               23
# Pop Culture                                23               24
# Hobbies & Interests                        24               25
# Books and Literature                       26               26
# Fine Art                                   28               27
# Pets                                       29               28
# Content Channel                            27               29
# Religion & Spirituality                    30               30

# %% [markdown]
# * Pageviews - Tier 2

# %%
pvs_eda(cat, 'tier2', drop_cols=True).head(20)
# Out:
# subscription_status     % of non_subscriber pvs % of subscriber pvs  \
# tier2
# Business                                   4.96               18.31
# Industries                                 4.69                8.43
# Economy                                    8.65                6.27
# Computing                                  5.35                6.20
# Politics                                  20.52                6.16
# Diseases and Conditions                    5.35                5.54
# Personal Investing                         4.15                5.04
# Personal Debt                              3.85                2.14
# Video Game Genres                          4.03                1.95
# Travel Type                                1.28                1.93
# Law                                        3.93                1.77
# Vaccines                                   1.81                1.71
# Consumer Electronics                       4.81                1.62
# PC Games                                   2.69                1.36
# Artificial Intelligence                    0.24                1.19
# Personal Taxes                             0.94                1.15
# Auto Type                                  0.70                1.11
# Job Search                                 0.57                1.03
# Remote Working                             0.21                0.88
# College Education                          0.45                0.87
#
# subscription_status      non_subscriber_rank  subscriber_rank
# tier2
# Business                                   5                1
# Industries                                 7                2
# Economy                                    2                3
# Computing                                  4                4
# Politics                                   1                5
# Diseases and Conditions                    3                6
# Personal Investing                         8                7
# Personal Debt                             11                8
# Video Game Genres                          9                9
# Travel Type                               15               10
# Law                                       10               11
# Vaccines                                  14               12
# Consumer Electronics                       6               13
# PC Games                                  13               14
# Artificial Intelligence                   37               15
# Personal Taxes                            18               16
# Auto Type                                 21               17
# Job Search                                24               18
# Remote Working                            40               19
# College Education                         25               20

# %% [markdown]
# * Pageviews - Primary Channel

# %%
pvs_eda(cat, 'GA_primaryChannel', drop_cols=True).head(20)
# Out:
# subscription_status % of non_subscriber pvs % of subscriber pvs  \
# GA_primaryChannel
# business                              30.90               22.37
# leadership                             9.73               22.26
# innovation                            25.55               19.77
# money                                 21.45               16.33
# lifestyle                              5.53                8.37
# small business                         1.02                4.00
# billionaires                           1.67                1.98
# real estate                            0.28                0.93
# consumer                               0.97                0.80
# shopping                               0.77                0.75
# asia                                   0.56                0.56
# entrepreneurs                          0.15                0.49
# tech                                   0.46                0.42
# industry                               0.51                0.30
# investing                              0.24                0.28
# newsletters                            0.06                0.17
# opinion                                0.06                0.09
# under 30                               0.02                0.06
# lists                                  0.02                0.04
# video                                  0.00                0.03
#
# subscription_status  non_subscriber_rank  subscriber_rank
# GA_primaryChannel
# business                               1                1
# leadership                             4                2
# innovation                             2                3
# money                                  3                4
# lifestyle                              5                5
# small business                         7                6
# billionaires                           6                7
# real estate                           13                8
# consumer                               8                9
# shopping                               9               10
# asia                                  10               11
# entrepreneurs                         15               12
# tech                                  12               13
# industry                              11               14
# investing                             14               15
# newsletters                           17               16
# opinion                               16               17
# under 30                              20               18
# lists                                 19               19
# video                                 22               20

# %%
# games
pvs_eda(cat, 'GA_primaryChannel', drop_cols=True).head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13965/2495405423.py in <module>
# ----> 1 pvs_eda(cat, 'GA_primaryChannel', drop_cols=True).head(20)
#
# NameError: name 'cat' is not defined

# %% [markdown]
# * Pageviews - Primary Section

# %%
pvs_eda(cat, 'GA_primarySection', drop_cols=True).head(20)
# Out:
# subscription_status       % of non_subscriber pvs % of subscriber pvs  \
# GA_primarySection
# careers                                      3.28                6.56
# leadership strategy                          3.47                5.90
# games                                       10.85                5.80
# travel                                       3.48                4.74
# markets                                      6.51                4.65
# forbeswomen                                  2.10                4.59
# personal finance                            10.64                4.21
# hollywood & entertainment                    3.03                3.98
# crypto & blockchain                          5.55                3.88
# entrepreneurs                                1.35                3.85
# investing                                    3.27                3.33
# retail                                       0.89                3.22
# consumer tech                                9.44                3.12
# cmo network                                  0.52                3.01
# sportsmoney                                  2.62                2.34
# taxes                                        1.21                2.20
# healthcare                                   2.56                2.18
# enterprise tech                              0.47                2.14
# transportation                               0.81                1.78
# food & drink                                 0.38                1.74
#
# subscription_status        non_subscriber_rank  subscriber_rank
# GA_primarySection
# careers                                     11                1
# leadership strategy                          9                2
# games                                        1                3
# travel                                       8                4
# markets                                      4                5
# forbeswomen                                 16                6
# personal finance                             2                7
# hollywood & entertainment                   13                8
# crypto & blockchain                          5                9
# entrepreneurs                               21               10
# investing                                   12               11
# retail                                      25               12
# consumer tech                                3               13
# cmo network                                 30               14
# sportsmoney                                 14               15
# taxes                                       22               16
# healthcare                                  15               17
# enterprise tech                             32               18
# transportation                              26               19
# food & drink                                35               20

# %% [markdown]
# ### Avg. TOP in various content categories
# * Content categories = IAB Tier 1, Tier 2

# %%
t1 = cat.pivot_table(index=['GA_fullVisitorId'], 
                     columns='tier1',
                     values=['timeOnPage', 'GA_pageViews'], 
                     aggfunc='sum', 
                     fill_value=0).reset_index()
# set aside fvids
fvids = list(t1.GA_fullVisitorId)

# calc avg. top
t1_top = t1["timeOnPage"]/t1["GA_pageViews"]
t1_top = t1_top.fillna(0)

t1_top["GA_fullVisitorId"] = fvids
t1_top = pd.merge(t1_top, target_class, how="left", on="GA_fullVisitorId")

# %% [markdown]
# * Average time on page - Tier 1

# %%
top_eda(t1_top).rename(columns={'non_subscriber': 'non_subscriber avg. top', 'subscriber': 'subscriber avg. top'})
# Out:
# subscription_status       non_subscriber avg. top  subscriber avg. top  \
# Business and Finance                        56.54               129.02
# Personal Finance                            43.94                83.60
# Technology & Computing                      35.33                71.38
# Medical Health                              32.60                67.43
# News and Politics                           45.96                66.41
# Careers                                     11.83                39.00
# Travel                                      18.57                37.14
# Shopping                                    10.98                32.61
# Style & Fashion                              8.83                31.28
# Sports                                      13.40                29.33
# Education                                    9.85                28.97
# Food & Drink                                 8.37                27.90
# Automotive                                  11.09                27.75
# Real Estate                                 10.02                25.86
# Events and Attractions                       7.80                24.38
# Science                                     11.67                22.71
# Television                                  11.57                22.22
# Healthy Living                               7.05                20.69
# Home & Garden                                7.60                18.86
# Video Gaming                                16.45                15.25
# Family and Relationships                     4.97                14.66
# Movies                                       8.35                14.18
# Music and Audio                              7.10                13.86
# Pop Culture                                  6.55                12.47
# Hobbies & Interests                          5.46                10.13
# Books and Literature                         2.42                 7.89
# Fine Art                                     2.20                 5.53
# Pets                                         1.31                 4.89
# Content Channel                              1.92                 3.17
# Religion & Spirituality                      0.72                 1.92
#
# subscription_status       non_subscriber_rank  subscriber_rank
# Business and Finance                        1                1
# Personal Finance                            3                2
# Technology & Computing                      4                3
# Medical Health                              5                4
# News and Politics                           2                5
# Careers                                     9                6
# Travel                                      6                7
# Shopping                                   13                8
# Style & Fashion                            16                9
# Sports                                      8               10
# Education                                  15               11
# Food & Drink                               17               12
# Automotive                                 12               13
# Real Estate                                14               14
# Events and Attractions                     19               15
# Science                                    10               16
# Television                                 11               17
# Healthy Living                             22               18
# Home & Garden                              20               19
# Video Gaming                                7               20
# Family and Relationships                   25               21
# Movies                                     18               22
# Music and Audio                            21               23
# Pop Culture                                23               24
# Hobbies & Interests                        24               25
# Books and Literature                       26               26
# Fine Art                                   27               27
# Pets                                       29               28
# Content Channel                            28               29
# Religion & Spirituality                    30               30

# %% [markdown]
# * Average time on page - Tier 2

# %%
t2 = cat.pivot_table(index=['GA_fullVisitorId'], 
                     columns='tier2',
                     values=['timeOnPage', 'GA_pageViews'], 
                     aggfunc='sum', 
                     fill_value=0).reset_index()
# set aside fvids
fvids = list(t2.GA_fullVisitorId)

# calc avg. top
t2_top = t2["timeOnPage"]/t2["GA_pageViews"]
t2_top = t2_top.fillna(0)

t2_top["GA_fullVisitorId"] = fvids
t2_top = pd.merge(t2_top, target_class, how="left", on="GA_fullVisitorId")

top_eda(t2_top).rename(columns={'non_subscriber': 'non_subscriber avg. top', 'subscriber': 'subscriber avg. top'}).head(15)
# Out:
# subscription_status      non_subscriber avg. top  subscriber avg. top  \
# Business                                   33.18               105.75
# Industries                                 31.00                81.20
# Computing                                  28.62                59.54
# Economy                                    33.50                59.38
# Personal Investing                         25.03                56.94
# Diseases and Conditions                    25.82                56.39
# Politics                                   37.92                43.18
# Law                                        23.33                27.50
# Personal Debt                              18.23                26.79
# Travel Type                                12.90                26.29
# Vaccines                                   16.03                25.93
# Consumer Electronics                       18.78                25.76
# Job Search                                  7.21                22.22
# Personal Taxes                             10.76                19.31
# Remote Working                              3.40                19.19
#
# subscription_status      non_subscriber_rank  subscriber_rank
# Business                                   3                1
# Industries                                 4                2
# Computing                                  5                3
# Economy                                    2                4
# Personal Investing                         7                5
# Diseases and Conditions                    6                6
# Politics                                   1                7
# Law                                        8                8
# Personal Debt                             10                9
# Travel Type                               13               10
# Vaccines                                  11               11
# Consumer Electronics                       9               12
# Job Search                                21               13
# Personal Taxes                            16               14
# Remote Working                            38               15

# %% [markdown]
# ### Avg. article views in each month

# %%
user_per_mon = pd.DataFrame(content.groupby(['GA_fullVisitorId', 'subscription_status', 'mon_year']).GA_cmsNaturalId.count()).reset_index().rename(columns=
                                                                                                                                                   {'GA_cmsNaturalId':'total_article_views'})
user_per_mon
# Out:
#              GA_fullVisitorId subscription_status mon_year  \
# 0        10000058813304965608      non_subscriber  2020-02
# 1        10000058813304965608      non_subscriber  2020-03
# 2        10000058813304965608      non_subscriber  2020-04
# 3        10000058813304965608      non_subscriber  2020-05
# 4        10000058813304965608      non_subscriber  2020-06
# ...                       ...                 ...      ...
# 1038067   9999883233119772718      non_subscriber  2020-01
# 1038068   9999883233119772718      non_subscriber  2020-10
# 1038069   9999883233119772718      non_subscriber  2021-01
# 1038070   9999883233119772718      non_subscriber  2021-05
# 1038071   9999953169198331967      non_subscriber  2021-07
#
#          total_article_views
# 0                          6
# 1                         14
# 2                         13
# 3                         27
# 4                         15
# ...                      ...
# 1038067                    1
# 1038068                    2
# 1038069                    1
# 1038070                    6
# 1038071                    5
#
# [1038072 rows x 4 columns]

# %% [markdown]
# * Avg(articles per month)

# %%
per_mon =  pd.DataFrame(user_per_mon.groupby(['GA_fullVisitorId', 'subscription_status']).total_article_views.mean()).reset_index()

per_mon.GA_cmsNaturalId = per_mon.total_article_views.round()
per_mon
# Out:
#             GA_fullVisitorId subscription_status  total_article_views
# 0       10000058813304965608      non_subscriber                 9.52
# 1       10000251105399450511      non_subscriber                 8.92
# 2       10000610991313890343      non_subscriber                 2.40
# 3        1000096511026234346          subscriber                 6.00
# 4        1000104336364784244          subscriber                 3.81
# ...                      ...                 ...                  ...
# 203780   9999629024408201784      non_subscriber                 2.33
# 203781    999969109989075422      non_subscriber                 2.70
# 203782   9999757056159711694      non_subscriber                11.47
# 203783   9999883233119772718      non_subscriber                 2.20
# 203784   9999953169198331967      non_subscriber                 5.00
#
# [203785 rows x 3 columns]

# %%
per_mon.groupby('subscription_status').total_article_views.describe().T
# Out:
# subscription_status  non_subscriber  subscriber
# count                     109738.00    94047.00
# mean                           6.44       13.69
# std                            9.54       30.80
# min                            1.39        1.00
# 25%                            3.50        4.50
# 50%                            5.00        8.00
# 75%                            7.00       15.00
# max                         2064.80     3740.00

# %%
# example non-subs
user_per_mon[user_per_mon.GA_fullVisitorId=='10000058813304965608']
# Out:
#         GA_fullVisitorId subscription_status mon_year  GA_cmsNaturalId
# 0   10000058813304965608      non_subscriber  2020-02                6
# 1   10000058813304965608      non_subscriber  2020-03               14
# 2   10000058813304965608      non_subscriber  2020-04               13
# 3   10000058813304965608      non_subscriber  2020-05               27
# 4   10000058813304965608      non_subscriber  2020-06               15
# 5   10000058813304965608      non_subscriber  2020-07                9
# 6   10000058813304965608      non_subscriber  2020-08                1
# 7   10000058813304965608      non_subscriber  2020-09               13
# 8   10000058813304965608      non_subscriber  2020-10               23
# 9   10000058813304965608      non_subscriber  2020-11               13
# 10  10000058813304965608      non_subscriber  2020-12                7
# 11  10000058813304965608      non_subscriber  2021-01               11
# 12  10000058813304965608      non_subscriber  2021-02               15
# 13  10000058813304965608      non_subscriber  2021-03                5
# 14  10000058813304965608      non_subscriber  2021-04                6
# 15  10000058813304965608      non_subscriber  2021-05                4
# 16  10000058813304965608      non_subscriber  2021-06                3
# 17  10000058813304965608      non_subscriber  2021-07                9
# 18  10000058813304965608      non_subscriber  2021-08                4
# 19  10000058813304965608      non_subscriber  2021-09                1
# 20  10000058813304965608      non_subscriber  2021-10                1

# %%
# example subs
user_per_mon[user_per_mon.GA_fullVisitorId=='3857395123229566996']
# Out:
#            GA_fullVisitorId subscription_status mon_year  GA_cmsNaturalId
# 491055  3857395123229566996          subscriber  2020-03                2
# 491056  3857395123229566996          subscriber  2020-04               10
# 491057  3857395123229566996          subscriber  2020-05                5
# 491058  3857395123229566996          subscriber  2020-06               12
# 491059  3857395123229566996          subscriber  2020-07                8
# 491060  3857395123229566996          subscriber  2020-08                9
# 491061  3857395123229566996          subscriber  2020-09                1
# 491062  3857395123229566996          subscriber  2020-10               10
# 491063  3857395123229566996          subscriber  2020-11                8
# 491064  3857395123229566996          subscriber  2020-12               17
# 491065  3857395123229566996          subscriber  2021-01                4
# 491066  3857395123229566996          subscriber  2021-02               10
# 491067  3857395123229566996          subscriber  2021-03               10

# %%
# example subs
user_per_mon[user_per_mon.GA_fullVisitorId=='5277846215104667271']
# Out:
#            GA_fullVisitorId subscription_status mon_year  GA_cmsNaturalId
# 627088  5277846215104667271          subscriber  2020-03                3
# 627089  5277846215104667271          subscriber  2020-04               38
# 627090  5277846215104667271          subscriber  2020-05               34
# 627091  5277846215104667271          subscriber  2020-06               96
# 627092  5277846215104667271          subscriber  2020-07               38
# 627093  5277846215104667271          subscriber  2020-08               69
# 627094  5277846215104667271          subscriber  2020-09               42
# 627095  5277846215104667271          subscriber  2020-10               55
# 627096  5277846215104667271          subscriber  2020-11               73
# 627097  5277846215104667271          subscriber  2020-12              109
# 627098  5277846215104667271          subscriber  2021-01              145
# 627099  5277846215104667271          subscriber  2021-02               48
# 627100  5277846215104667271          subscriber  2021-03              150
# 627101  5277846215104667271          subscriber  2021-04               78
# 627102  5277846215104667271          subscriber  2021-05               81
# 627103  5277846215104667271          subscriber  2021-06               10
# 627104  5277846215104667271          subscriber  2021-07               11

# %%
# joining with C-levels for curiosity

start_time = time.time()

sql = """
    SELECT 
        *
      FROM (
        SELECT 
            DISTINCT *,
            RANK() OVER (PARTITION BY GA_fullVisitorId ORDER BY date DESC) AS mostrecent,
        FROM
            `api-project-901373404215.lookalike.zoom_info_c_level`
          )
      WHERE 
          mostrecent = 1
"""

clevels = (
    bqclient.query(sql)
    .result()
    .to_dataframe(bqstorage_client=bqstorageclient)
) 

print("--- %s seconds ---" % (time.time() - start_time)) #12.45

# %%
clevels
