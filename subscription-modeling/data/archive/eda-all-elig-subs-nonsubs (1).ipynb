# %%
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.2f' % x)
import numpy as np
from google.cloud import bigquery
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style('darkgrid')
import joblib
import warnings
warnings.filterwarnings('ignore') 
import re

bq_client = bigquery.Client()

# %%
import google.auth
from google.cloud import bigquery
from google.cloud import bigquery_storage
import time

bqclient = bigquery.Client()
bqstorageclient = bigquery_storage.BigQueryReadClient()

# %%
def pvs_eda(input_df, cat_col_name, drop_cols=False):
    
    # pivot
    df_cat = pd.pivot_table(
        input_df, 
        values='GA_pageViews',
        columns= cat_col_name,
        index='subscription_status',
        aggfunc='sum')\
        .reset_index()
    
    # drop none and other cols
    if drop_cols==True:
        
        if 'none' in list(df_cat.columns):
            df_cat.drop('none', axis=1, inplace=True)
        
        if 'other' in list(df_cat.columns):
            df_cat.drop('other', axis=1, inplace=True)

    
    # percentage calc below
    df_cat = df_cat.fillna(0)
    df_cat = df_cat.T
    
    new_header = df_cat.iloc[0] # grab the first row for the header
    df_cat = df_cat[1:] # take the data minus the header row
    df_cat.columns = new_header
  
    df_cat['% of non_subscriber pvs'] = (df_cat['non_subscriber'] / df_cat['non_subscriber'].sum()) * 100
    df_cat['% of subscriber pvs'] = (df_cat['subscriber'] / df_cat['subscriber'].sum()) * 100
    
    df_cat.drop(['non_subscriber', 'subscriber'], axis=1, inplace=True)

    df_cat['non_subscriber_rank'] = df_cat['% of non_subscriber pvs'].rank(ascending=False).astype(int)
    df_cat['subscriber_rank'] = df_cat['% of subscriber pvs'].rank(ascending=False).astype(int)

    df_cat = df_cat.sort_values('subscriber_rank')
    
    return df_cat

# %%
def top_eda(df):
    '''
    Prep df for eda
    '''
    # remove column = "none" i.e. Tier 1/Tier2/PC/PS was not available
    df.drop("none", axis=1, inplace=True)
    
    # group all subscribers, calculate mean of their (avg. time on page) for each category. Same for Non-subscribers
    df = df.groupby('subscription_status').mean().T
    
    # assign rank
    df['non_subscriber_rank'] = df['non_subscriber'].rank(ascending=False).astype(int)
    df['subscriber_rank'] = df['subscriber'].rank(ascending=False).astype(int)
    df = df.sort_values('subscriber_rank')

    return df

# %% [markdown]
# ## DATA

# %%
start_time = time.time()

query_string = """
  SELECT
       *
    FROM
        `api-project-901373404215.skt.sm_subs_ga`
"""

subs_data = (
    bqclient.query(query_string)
    .result()
    .to_dataframe(bqstorage_client=bqstorageclient)
) 

print("--- %s seconds ---" % (time.time() - start_time))

subs_data["subscription_status"] = "subscriber"

# drop unnecessary col & rename
subs_data.drop(['user_id_uid', 'resource_id_rid'], axis=1, inplace=True)
subs_data.rename(columns={'ga_pianoId': 'piano_id'}, inplace=True)

print(subs_data.shape)
print("Unique unlimited subscribers: ", len(subs_data.piano_id.unique()))
print("Unique unlimited fullvids: ", len(subs_data.GA_fullVisitorId.unique()), "\n")

subs_data.head()
# Out:
# --- 18.09546947479248 seconds ---
# (6636071, 23)
# Unique unlimited subscribers:  41716
# Unique unlimited fullvids:  99096
#           piano_id     GA_fullVisitorId  GA_visitStartTime     GA_date  \
# 0  pni6dibvvqpayzs  3174777614220968107         1619791110  2021-04-30
# 1  pninjgwtnqj8to8  7616931455160605539         1611070104  2021-01-19
# 2  pnidl2xoeqz0wr2  1121210302312468443         1626184986  2021-07-13
# 3  pnixmwdpeqjjb7b  7219142532098579810         1621515712  2021-05-20
# 4  pniluxtn9qn8sos  7600114442027281591         1634087240  2021-10-12
#
#                                          GA_pagePath  \
# 0                                 /sites/jefftaylor/
# 1                                 /sites/jeffsteele/
# 2  /sites/forbesagencycouncil/2017/12/06/the-sing...
# 3  /sites/sap/2021/05/12/how-hybrid-remote-work-i...
# 4                                                  /
#
#                        GA_dfpNewZone  GA_visitNumber  GA_pageViews  \
# 0                               none              14             1
# 1                               none              90             1
# 2  article/standard/default/standard              12             1
# 3  article/standard/default/standard               2             1
# 4                               none               6             1
#
#    GA_scrollDepth  timeOnPage  ... GA_deviceOperatingSystem GA_deviceCategory  \
# 0            0.50       14.00  ...                macintosh           desktop
# 1            0.00      235.00  ...                  windows           desktop
# 2            0.50      452.00  ...                  windows           desktop
# 3            0.00       62.00  ...                      ios            mobile
# 4            0.20      106.00  ...                  windows           desktop
#
#   GA_deviceBrowser     GA_country GA_referralGroup GA_primaryChannel  \
# 0           chrome  united states   organic search        innovation
# 1           chrome    puerto rico   organic search       real estate
# 2             edge  united states   organic search        leadership
# 3           safari  united states       newsletter        innovation
# 4           chrome  united states           direct              home
#
#   GA_primarySection tier1 tier2 subscription_status
# 0              none  None  None          subscriber
# 1              none  None  None          subscriber
# 2              none  None  None          subscriber
# 3              none  None  None          subscriber
# 4              none  None  None          subscriber
#
# [5 rows x 23 columns]

# %%
start_time = time.time()

query_string = """
  SELECT
       *
    FROM
        `api-project-901373404215.skt.sm_nonsubs_ga`
"""

nonsubs_data = (
    bqclient.query(query_string)
    .result()
    .to_dataframe(bqstorage_client=bqstorageclient)
) 

print("--- %s seconds ---" % (time.time() - start_time))

nonsubs_data["subscription_status"] = "non_subscriber"

print("Before removing suspicious fvids:", nonsubs_data.shape)
print("Unique unlimited fullvids: ", len(nonsubs_data.GA_fullVisitorId.unique()), "\n")

# it was noted that some suspicious fvids have no pianoID but their dfpZone has 'subscriber' in it - remove them

nonsubs_data.GA_dfpNewZone = nonsubs_data.GA_dfpNewZone.fillna('none')
suspicious_fvid = nonsubs_data[nonsubs_data.GA_dfpNewZone.str.contains('/subscriber/')].GA_fullVisitorId.unique()

print("After removing ", len(suspicious_fvid), "suspicious fvids:", nonsubs_data.shape)
nonsubs_data = nonsubs_data[~nonsubs_data.GA_fullVisitorId.isin(suspicious_fvid)]

print("Unique unlimited fullvids: ", len(nonsubs_data.GA_fullVisitorId.unique()), "\n")

nonsubs_data.head()
# Out:
# --- 10.969189882278442 seconds ---
# Before removing suspicious fvids: (1231590, 23)
# Unique unlimited fullvids:  410000
#
# After removing  12 suspicious fvids: (1231590, 23)
# Unique unlimited fullvids:  409988
#   piano_id      GA_fullVisitorId  GA_visitStartTime     GA_date  \
# 0     None   8738220177769013662         1630523553  2021-09-01
# 1     None   7907834872961320899         1632520131  2021-09-24
# 2     None   5408030440582556413         1634478845  2021-10-17
# 3     None   5783491991586390106         1634088981  2021-10-12
# 4     None  13276614681697164378         1633348653  2021-10-04
#
#                                          GA_pagePath  \
# 0                                   /companies/loom/
# 1                              /top-wealth-advisors/
# 2                                /sites/joshuadines/
# 3                                 /sites/arielcohen/
# 4  /sites/petercohan/2012/02/19/jurassic-park-how...
#
#                            GA_dfpNewZone  GA_visitNumber  GA_pageViews  \
# 0                                   none               4             1
# 1                                   none               1             1
# 2                                   none               1             1
# 3                                   none               2             1
# 4  article-amp/standard/default/standard               1             1
#
#    GA_scrollDepth  timeOnPage  ... GA_deviceOperatingSystem GA_deviceCategory  \
# 0            0.25        4.00  ...                  windows           desktop
# 1            1.00        3.00  ...                  windows           desktop
# 2            0.25        7.00  ...                  windows           desktop
# 3            0.25        4.00  ...                  windows           desktop
# 4            0.50      176.00  ...                  windows           desktop
#
#   GA_deviceBrowser     GA_country       GA_referralGroup GA_primaryChannel  \
# 0             edge  united states         organic search              none
# 1             edge  united states         organic search           advisor
# 2             edge  united states                 direct          consumer
# 3             edge  united states  organic social (dark)          business
# 4             edge  united states               referral             money
#
#                     GA_primarySection tier1 tier2 subscription_status
# 0                                none  None  None      non_subscriber
# 1  america's top wealth advisors 2021  None  None      non_subscriber
# 2                         sportsmoney  None  None      non_subscriber
# 3                              energy  None  None      non_subscriber
# 4                             markets  None  None      non_subscriber
#
# [5 rows x 23 columns]

# %%
# any col names mismatch? - no

[x for x in list(subs_data.columns) if x not in list(nonsubs_data.columns)]
# Out:
# []

# %%
df = pd.concat([subs_data, nonsubs_data])

print("Shape: ", df.shape)

# fill na
df.GA_cmsNaturalId = df.GA_cmsNaturalId.fillna('None') 

# short list device OS
shortlisted_os = ["android", "ios", "macintosh", "windows"]

df["deviceOS"] = np.where(df["GA_deviceOperatingSystem"].isin(shortlisted_os), 
                          df["GA_deviceOperatingSystem"], 
                          "other")

df[['GA_fullVisitorId', 'subscription_status']].drop_duplicates(keep='first').subscription_status.value_counts()
# Out:
# Shape:  (7866937, 23)
# non_subscriber    409988
# subscriber         99096
# Name: subscription_status, dtype: int64

# %%
df[['GA_fullVisitorId', 'subscription_status']].drop_duplicates(keep='first').subscription_status.value_counts(normalize=True)
# Out:
# non_subscriber   0.81
# subscriber       0.19
# Name: subscription_status, dtype: float64

# %%
df.head()
# Out:
#           piano_id     GA_fullVisitorId  GA_visitStartTime     GA_date  \
# 0  pni6dibvvqpayzs  3174777614220968107         1619791110  2021-04-30
# 1  pninjgwtnqj8to8  7616931455160605539         1611070104  2021-01-19
# 2  pnidl2xoeqz0wr2  1121210302312468443         1626184986  2021-07-13
# 3  pnixmwdpeqjjb7b  7219142532098579810         1621515712  2021-05-20
# 4  pniluxtn9qn8sos  7600114442027281591         1634087240  2021-10-12
#
#                                          GA_pagePath  \
# 0                                 /sites/jefftaylor/
# 1                                 /sites/jeffsteele/
# 2  /sites/forbesagencycouncil/2017/12/06/the-sing...
# 3  /sites/sap/2021/05/12/how-hybrid-remote-work-i...
# 4                                                  /
#
#                        GA_dfpNewZone  GA_visitNumber  GA_pageViews  \
# 0                               none              14             1
# 1                               none              90             1
# 2  article/standard/default/standard              12             1
# 3  article/standard/default/standard               2             1
# 4                               none               6             1
#
#    GA_scrollDepth  timeOnPage  ... GA_deviceCategory GA_deviceBrowser  \
# 0            0.50       14.00  ...           desktop           chrome
# 1            0.00      235.00  ...           desktop           chrome
# 2            0.50      452.00  ...           desktop             edge
# 3            0.00       62.00  ...            mobile           safari
# 4            0.20      106.00  ...           desktop           chrome
#
#       GA_country GA_referralGroup GA_primaryChannel GA_primarySection tier1  \
# 0  united states   organic search        innovation              none  None
# 1    puerto rico   organic search       real estate              none  None
# 2  united states   organic search        leadership              none  None
# 3  united states       newsletter        innovation              none  None
# 4  united states           direct              home              none  None
#
#   tier2 subscription_status   deviceOS
# 0  None          subscriber  macintosh
# 1  None          subscriber    windows
# 2  None          subscriber    windows
# 3  None          subscriber        ios
# 4  None          subscriber    windows
#
# [5 rows x 24 columns]

# %%
target_class = df[['GA_fullVisitorId', 'subscription_status']].drop_duplicates(keep='first')

# %% [markdown]
# ## EDA

# %% [markdown]
# ### User's whole behavior
# **i.e., avg. top and sum(pvs) over whole GA history**

# %%
whole = df.groupby(['GA_fullVisitorId', 'subscription_status']).agg({'GA_pageViews': 'sum', 'timeOnPage': 'sum'}).reset_index().rename(columns={'GA_pageViews': 'sum_pvs'})
whole["avg_top"] = whole['timeOnPage']/whole['sum_pvs']

whole
# Out:
#             GA_fullVisitorId subscription_status  sum_pvs  timeOnPage  avg_top
# 0        1000000948120006249      non_subscriber        1      521.00   521.00
# 1       10000078774942201969      non_subscriber        5      228.00    45.60
# 2       10000093321793562421      non_subscriber        1        0.00     0.00
# 3       10000127776222822445      non_subscriber        1        9.00     9.00
# 4       10000206856643135086      non_subscriber        5      406.00    81.20
# ...                      ...                 ...      ...         ...      ...
# 509079   9999428991944010204          subscriber       22     3780.00   171.82
# 509080   9999453033634739955      non_subscriber        1       97.00    97.00
# 509081   9999617506304669367      non_subscriber        1       52.00    52.00
# 509082   9999621821965685242      non_subscriber        1       12.00    12.00
# 509083   9999737912842746322      non_subscriber        1       23.00    23.00
#
# [509084 rows x 5 columns]

# %% [markdown]
# * Distribution of sum(pvs)
#     * Subs typically have more pvs than non-subs

# %%
whole.groupby('subscription_status').sum_pvs.describe().T
# Out:
# subscription_status  non_subscriber  subscriber
# count                     409988.00    99096.00
# mean                           3.00       66.97
# std                            6.81      364.58
# min                            1.00        1.00
# 25%                            1.00        9.00
# 50%                            1.00       22.00
# 75%                            3.00       56.00
# max                         2242.00    44770.00

# %% [markdown]
# * Distribution of avg(top)
#     * Subs spend more avg. top than non-subs on a whole

# %%
whole.groupby('subscription_status').avg_top.describe().T
# Out:
# subscription_status  non_subscriber  subscriber
# count                     409988.00    99096.00
# mean                          72.66      135.43
# std                          122.61      105.12
# min                            0.00        0.00
# 25%                            7.00       65.25
# 50%                           36.50      113.94
# 75%                           88.00      177.65
# max                         3364.00     2497.00

# %% [markdown]
# ### Users' Unique Pageviews in each session (avg, median)

# %%
# user's per pagepath GA data
page = df.groupby(['GA_fullVisitorId', 'GA_visitStartTime', 'GA_pagePath']).agg({'GA_pageViews': 'max', 'GA_scrollDepth': 'max', 'timeOnPage': 'sum'}).reset_index()

# user's per session GA data
session = page.groupby(['GA_fullVisitorId', 'GA_visitStartTime']).agg({'GA_pageViews': 'sum', 'GA_scrollDepth': 'mean', 'timeOnPage': 'mean'}).reset_index()

session.rename(columns={'GA_pageViews': 'unique_pageViews', 'timeOnPage': 'top_per_session'}, inplace=True)
session
# Out:
#              GA_fullVisitorId  GA_visitStartTime  unique_pageViews  \
# 0         1000000948120006249         1635456756                 1
# 1        10000078774942201969         1629090740                 1
# 2        10000078774942201969         1632746707                 2
# 3        10000078774942201969         1634413951                 1
# 4        10000093321793562421         1635454123                 1
# ...                       ...                ...               ...
# 3296967   9999428991944010204         1631618760                 1
# 3296968   9999453033634739955         1633461706                 1
# 3296969   9999617506304669367         1633783846                 1
# 3296970   9999621821965685242         1633456653                 1
# 3296971   9999737912842746322         1635299022                 1
#
#          GA_scrollDepth  top_per_session
# 0                  0.25           521.00
# 1                  0.25            15.00
# 2                  1.00            91.50
# 3                  0.75            30.00
# 4                  0.00             0.00
# ...                 ...              ...
# 3296967            0.25            22.00
# 3296968            0.75            97.00
# 3296969            0.50            52.00
# 3296970            0.50            12.00
# 3296971            0.00            23.00
#
# [3296972 rows x 5 columns]

# %%
pageViews = session.groupby('GA_fullVisitorId').agg({'unique_pageViews': ['mean', 'median']}).reset_index()

# rename cols
pageViews.columns = [' '.join(col).strip() for col in pageViews.columns.values]
pageViews.rename(columns={'unique_pageViews mean':'unique_pageviews_mean', 'unique_pageViews median': 'unique_pageviews_median'}, inplace=True)

# join target class
pageViews = pd.merge(pageViews, target_class, how="left", on = "GA_fullVisitorId")
pageViews
# Out:
#             GA_fullVisitorId  unique_pageviews_mean  unique_pageviews_median  \
# 0        1000000948120006249                   1.00                     1.00
# 1       10000078774942201969                   1.33                     1.00
# 2       10000093321793562421                   1.00                     1.00
# 3       10000127776222822445                   1.00                     1.00
# 4       10000206856643135086                   1.00                     1.00
# ...                      ...                    ...                      ...
# 509079   9999428991944010204                   1.19                     1.00
# 509080   9999453033634739955                   1.00                     1.00
# 509081   9999617506304669367                   1.00                     1.00
# 509082   9999621821965685242                   1.00                     1.00
# 509083   9999737912842746322                   1.00                     1.00
#
#        subscription_status
# 0           non_subscriber
# 1           non_subscriber
# 2           non_subscriber
# 3           non_subscriber
# 4           non_subscriber
# ...                    ...
# 509079          subscriber
# 509080      non_subscriber
# 509081      non_subscriber
# 509082      non_subscriber
# 509083      non_subscriber
#
# [509084 rows x 4 columns]

# %% [markdown]
# * Average and Median of (unique pageviews in each sessions)
#
#     * Avg. pv per session is more for subs
#     * Median pv per session is 1 for the most part as expected w/ subs median being slighlty higher

# %%
pageViews.groupby('subscription_status').unique_pageviews_mean.describe().T
# Out:
# subscription_status  non_subscriber  subscriber
# count                     409988.00    99096.00
# mean                           1.02        2.30
# std                            0.20        4.45
# min                            1.00        1.00
# 25%                            1.00        1.33
# 50%                            1.00        1.73
# 75%                            1.00        2.47
# max                           58.00      356.00

# %%
pageViews.groupby('subscription_status').unique_pageviews_median.describe().T
# Out:
# subscription_status  non_subscriber  subscriber
# count                     409988.00    99096.00
# mean                           1.01        1.88
# std                            0.19        4.44
# min                            1.00        1.00
# 25%                            1.00        1.00
# 50%                            1.00        1.00
# 75%                            1.00        2.00
# max                           58.00      356.00

# %% [markdown]
# ### Users' Time on Page in each session (avg, median)

# %%
timeOnPage = session.groupby('GA_fullVisitorId').agg({'top_per_session': ['mean', 'median']}).reset_index()

# rename cols
timeOnPage.columns = [' '.join(col).strip() for col in timeOnPage.columns.values]
timeOnPage.rename(columns={'top_per_session mean':'top_mean', 'top_per_session median': 'top_median'}, inplace=True)

# join target class
timeOnPage = pd.merge(timeOnPage, target_class, how="left", on = "GA_fullVisitorId")
timeOnPage
# Out:
#             GA_fullVisitorId  top_mean  top_median subscription_status
# 0        1000000948120006249    521.00      521.00      non_subscriber
# 1       10000078774942201969     45.50       30.00      non_subscriber
# 2       10000093321793562421      0.00        0.00      non_subscriber
# 3       10000127776222822445      9.00        9.00      non_subscriber
# 4       10000206856643135086     81.20       32.00      non_subscriber
# ...                      ...       ...         ...                 ...
# 509079   9999428991944010204    157.59       73.25          subscriber
# 509080   9999453033634739955     97.00       97.00      non_subscriber
# 509081   9999617506304669367     52.00       52.00      non_subscriber
# 509082   9999621821965685242     12.00       12.00      non_subscriber
# 509083   9999737912842746322     23.00       23.00      non_subscriber
#
# [509084 rows x 4 columns]

# %% [markdown]
# * Average and Median of (sum of time on page in each session)
#
#     * Both avg and median distributions for subscribers are higher than non-subs

# %%
timeOnPage.groupby('subscription_status').top_mean.describe().T
# Out:
# subscription_status  non_subscriber  subscriber
# count                     409988.00    99096.00
# mean                          80.19      205.58
# std                          153.09      325.75
# min                            0.00        0.00
# 25%                            7.00       82.12
# 50%                           37.00      143.30
# 75%                           90.83      243.17
# max                         4444.00    33517.00

# %%
timeOnPage.groupby('subscription_status').top_median.describe().T
# Out:
# subscription_status  non_subscriber  subscriber
# count                     409988.00    99096.00
# mean                          70.39      122.39
# std                          149.16      291.95
# min                            0.00        0.00
# 25%                            3.00       34.00
# 50%                           29.00       70.00
# 75%                           76.00      132.00
# max                         4444.00    33517.00

# %% [markdown]
# ### Pageviews in referral sources, country, device OS
#
# * Subs coming more from organic search, referral, newsletter, social
# * Non-subs more from content aggregators and direct in addition to organic search

# %%
pvs_eda(df, 'GA_referralGroup')
# Out:
# subscription_status     % of non_subscriber pvs % of subscriber pvs  \
# GA_referralGroup
# organic search                            54.53               65.92
# direct                                    21.64                8.72
# newsletter                                 0.02                8.62
# referral                                   0.40                7.74
# organic social (dark)                      2.86                4.31
# organic social (forbes)                    0.34                3.02
# content aggregators                       20.15                1.57
# paid search                                0.05                0.09
# paid display                               0.00                0.01
# paid web                                   0.01                0.01
# fbia                                       0.00                0.00
# paid social (dark)                         0.00                0.00
# paid social (forbes)                       0.00                0.00
#
# subscription_status      non_subscriber_rank  subscriber_rank
# GA_referralGroup
# organic search                             1                1
# direct                                     2                2
# newsletter                                 8                3
# referral                                   5                4
# organic social (dark)                      4                5
# organic social (forbes)                    6                6
# content aggregators                        3                7
# paid search                                7                8
# paid display                              11                9
# paid web                                   9               10
# fbia                                      10               11
# paid social (dark)                        12               12
# paid social (forbes)                      13               13

# %% [markdown]
# * Subs highest in US.
# * Non-subs presence is in other countries also

# %%
pvs_eda(df, 'GA_country').drop('(not set)').head(10)
# Out:
# subscription_status % of non_subscriber pvs % of subscriber pvs  \
# GA_country
# united states                         68.60               88.76
# russia                                 0.05                1.78
# canada                                 8.18                1.32
# united kingdom                         6.31                1.20
# japan                                  0.13                0.82
# australia                              3.65                0.67
# india                                  2.56                0.47
# singapore                              0.86                0.25
# germany                                0.46                0.21
# mexico                                 0.22                0.19
#
# subscription_status  non_subscriber_rank  subscriber_rank
# GA_country
# united states                          1                1
# russia                                52                2
# canada                                 2                3
# united kingdom                         3                4
# japan                                 28                5
# australia                              4                6
# india                                  5                8
# singapore                              6                9
# germany                                8               10
# mexico                                18               11

# %% [markdown]
# * Subs pvs highest from desktop
# * Non-subs pvs highest from phone

# %%
pvs_eda(df, 'deviceOS')
# Out:
# subscription_status % of non_subscriber pvs % of subscriber pvs  \
# deviceOS
# windows                                0.09               43.09
# macintosh                              0.35               40.59
# ios                                   45.46                8.68
# android                               54.05                7.09
# other                                  0.05                0.55
#
# subscription_status  non_subscriber_rank  subscriber_rank
# deviceOS
# windows                                4                1
# macintosh                              3                2
# ios                                    2                3
# android                                1                4
# other                                  5                5

# %% [markdown]
# ### Pageviews in various content categories
# * Content categories = IAB Tier 1, Tier 2, PC (shortlisted), PS (shortlisted)
# * NOTE: during modeling also - calculate percentage of pvs in each category

# %%
content = df.copy()

# extract the start of natid string
content["natid_start"] = content.GA_cmsNaturalId.str.split("/").str[0]

print("Shape before: ", content.shape)

# keep only blogs, slides, magazine
content = content[(content['natid_start'].str.contains('blogandpostid')) | (content['natid_start'].str.contains('blogandslideid')) | (content['natid_start'].str.contains('magazine'))]

print("Shape after: ", content.shape)

# get month-year
content.GA_date = pd.to_datetime(content.GA_date)
content["mon_year"] = content['GA_date'].dt.to_period('M')
# Out:
# Shape before:  (7866937, 25)
# Shape after:  (5493926, 25)

# %%
cat = content.copy()
cat.isna().sum()
# Out:
# piano_id                    1211957
# GA_fullVisitorId                  0
# GA_visitStartTime                 0
# GA_date                           0
# GA_pagePath                       0
# GA_dfpNewZone                     0
# GA_visitNumber                    0
# GA_pageViews                      0
# GA_scrollDepth               846409
# timeOnPage                   137018
# GA_cmsNaturalId                   0
# title                         32799
# publish_date                  32799
# GA_deviceOperatingSystem          0
# GA_deviceCategory                 0
# GA_deviceBrowser                  0
# GA_country                        0
# GA_referralGroup                  0
# GA_primaryChannel                 0
# GA_primarySection                 0
# tier1                       1034572
# tier2                       1393428
# subscription_status               0
# deviceOS                          0
# natid_start                       0
# mon_year                          0
# dtype: int64

# %%
print("Before - unique PC: ", len(cat.GA_primaryChannel.unique()))
print("Before - unique PS: ", len(cat.GA_primarySection.unique()), "\n")

shortlisted_channel = joblib.load("pri_channel_shortlisted.pkl")
shortlisted_section = joblib.load("pri_section_shortlisted.pkl")

# primary channel
cat["GA_primaryChannel"] = np.where(cat["GA_primaryChannel"].isin(shortlisted_channel), 
                                    cat["GA_primaryChannel"], "other")

# primary section 
cat["GA_primarySection"] = np.where(cat["GA_primarySection"].isin(shortlisted_section), 
                                    cat["GA_primarySection"], "other")

print("After shortlisting - unique PC: ", len(cat.GA_primaryChannel.unique()))
print("After shortlisting - unique PS: ", len(cat.GA_primarySection.unique()), "\n")

# fillna with 0
cat.timeOnPage = cat.timeOnPage.fillna(0)

# replace empty and NULL with "none"
cat.tier1 = cat.tier1.replace(r'^\s*$', "none", regex=True)
cat.tier1 = cat.tier1.fillna("none")

# replace empty and NULL with "none"
cat.tier2 = cat.tier2.replace(r'^\s*$', "none", regex=True)
cat.tier2 = cat.tier2.fillna("none")

print("Unique all T1s: ", len(cat.tier1.unique()))  
print("Unique all T2s: ", len(cat.tier1.unique()))
# Out:
# Before - unique PC:  32
# Before - unique PS:  120
#
# After shortlisting - unique PC:  24
# After shortlisting - unique PS:  50
#
# Unique all T1s:  31
# Unique all T2s:  31

# %% [markdown]
# * Pageviews - Tier 1
#
#     * Subs more likely to read
#         * Busi & Fin, Personal Fin, News & Politics, Careers, Travel
#     * Non-subs more likely to read
#         * Tech, Personal Finance, Video Gaming, Science, Television

# %%
pvs_eda(cat, 'tier1', drop_cols=True)
# Out:
# subscription_status      % of non_subscriber pvs % of subscriber pvs  \
# tier1
# Business and Finance                       14.51               32.62
# Personal Finance                           15.59               10.55
# News and Politics                           8.74                9.37
# Technology & Computing                     18.27                8.62
# Medical Health                              8.50                6.18
# Video Gaming                                9.90                3.33
# Travel                                      2.89                3.18
# Careers                                     1.03                2.60
# Sports                                      2.44                2.37
# Food & Drink                                0.88                2.20
# Style & Fashion                             1.35                2.19
# Automotive                                  1.78                1.89
# Shopping                                    0.98                1.88
# Education                                   0.54                1.79
# Real Estate                                 0.69                1.55
# Television                                  2.60                1.43
# Movies                                      1.40                1.42
# Events and Attractions                      0.60                1.21
# Science                                     2.48                1.18
# Healthy Living                              0.70                0.89
# Music and Audio                             0.98                0.83
# Home & Garden                               1.35                0.78
# Family and Relationships                    0.30                0.55
# Pop Culture                                 0.34                0.39
# Hobbies & Interests                         0.42                0.31
# Books and Literature                        0.12                0.23
# Fine Art                                    0.26                0.19
# Pets                                        0.26                0.17
# Content Channel                             0.08                0.07
# Religion & Spirituality                     0.03                0.04
#
# subscription_status       non_subscriber_rank  subscriber_rank
# tier1
# Business and Finance                        3                1
# Personal Finance                            2                2
# News and Politics                           5                3
# Technology & Computing                      1                4
# Medical Health                              6                5
# Video Gaming                                4                6
# Travel                                      7                7
# Careers                                    15                8
# Sports                                     10                9
# Food & Drink                               18               10
# Style & Fashion                            13               11
# Automotive                                 11               12
# Shopping                                   16               13
# Education                                  22               14
# Real Estate                                20               15
# Television                                  8               16
# Movies                                     12               17
# Events and Attractions                     21               18
# Science                                     9               19
# Healthy Living                             19               20
# Music and Audio                            17               21
# Home & Garden                              14               22
# Family and Relationships                   25               23
# Pop Culture                                24               24
# Hobbies & Interests                        23               25
# Books and Literature                       28               26
# Fine Art                                   26               27
# Pets                                       27               28
# Content Channel                            29               29
# Religion & Spirituality                    30               30

# %% [markdown]
# * Pageviews - Tier 2
#
#     * Subs more likely to read
#         * Busi, Industries, Economy, Diseases, Personal Investing
#     * Non-subs more likely to read
#         * Economy, Games, Computing, Personal Debt, Consumer Electronics

# %%
pvs_eda(cat, 'tier2', drop_cols=True).head(20)
# Out:
# subscription_status     % of non_subscriber pvs % of subscriber pvs  \
# tier2
# Business                                   4.62               19.32
# Industries                                 3.00                8.65
# Economy                                    7.85                6.69
# Computing                                 11.62                6.09
# Personal Investing                         4.70                5.37
# Politics                                   5.04                5.30
# Diseases and Conditions                    3.67                4.11
# Travel Type                                1.46                2.06
# Vaccines                                   2.87                2.05
# Personal Debt                              8.09                1.96
# Consumer Electronics                       7.81                1.61
# Law                                        1.76                1.57
# PC Games                                   3.44                1.54
# Video Game Genres                          4.83                1.31
# Auto Type                                  0.66                1.19
# Personal Taxes                             0.91                1.16
# Artificial Intelligence                    0.10                1.15
# Job Search                                 0.63                1.09
# Remote Working                             0.22                0.98
# College Education                          0.31                0.92
#
# subscription_status      non_subscriber_rank  subscriber_rank
# tier2
# Business                                   8                1
# Industries                                11                2
# Economy                                    3                3
# Computing                                  1                4
# Personal Investing                         7                5
# Politics                                   5                6
# Diseases and Conditions                    9                7
# Travel Type                               16                8
# Vaccines                                  12                9
# Personal Debt                              2               10
# Consumer Electronics                       4               11
# Law                                       15               12
# PC Games                                  10               13
# Video Game Genres                          6               14
# Auto Type                                 24               15
# Personal Taxes                            21               16
# Artificial Intelligence                   76               17
# Job Search                                25               18
# Remote Working                            44               19
# College Education                         36               20

# %% [markdown]
# * Pageviews - Primary Channel
#
#     * Subs more likely to read
#         * Busi, leadership, real estate, small business, billionaires, lifestyle
#     * Non-subs more likely to read
#         * Busi, innovation, money

# %%
pvs_eda(cat, 'GA_primaryChannel', drop_cols=True).head(20)
# Out:
# subscription_status % of non_subscriber pvs % of subscriber pvs  \
# GA_primaryChannel
# leadership                             5.15               23.24
# business                              18.49               22.94
# innovation                            39.66               18.52
# money                                 24.31               16.49
# lifestyle                              7.62                8.12
# small business                         1.11                4.48
# billionaires                           0.73                2.16
# real estate                            0.62                1.32
# shopping                               0.43                0.58
# asia                                   0.81                0.57
# entrepreneurs                          0.19                0.43
# tech                                   0.26                0.27
# newsletters                            0.04                0.24
# consumer                               0.15                0.20
# investing                              0.19                0.16
# opinion                                0.11                0.08
# industry                               0.05                0.07
# under 30                               0.02                0.05
# video                                  0.00                0.04
# lists                                  0.04                0.03
#
# subscription_status  non_subscriber_rank  subscriber_rank
# GA_primaryChannel
# leadership                             5                1
# business                               3                2
# innovation                             1                3
# money                                  2                4
# lifestyle                              4                5
# small business                         6                6
# billionaires                           8                7
# real estate                            9                8
# shopping                              10                9
# asia                                   7               10
# entrepreneurs                         12               11
# tech                                  11               12
# newsletters                           18               13
# consumer                              14               14
# investing                             13               15
# opinion                               15               16
# industry                              16               17
# under 30                              19               18
# video                                 20               19
# lists                                 17               20

# %% [markdown]
# * Pageviews - Primary Section
#
#     * Subs more likely to read
#         * careers, forbeswomen, leadership strategy, entrepreneurs, travel??
#     * Non-subs more likely to read
#         * games, crypto & blockchain, personal finance, consumer tech

# %%
pvs_eda(cat, 'GA_primarySection', drop_cols=True).head(20)
# Out:
# subscription_status       % of non_subscriber pvs % of subscriber pvs  \
# GA_primarySection
# careers                                      1.71                7.12
# leadership strategy                          1.11                6.35
# games                                       14.83                5.22
# crypto & blockchain                          9.84                5.00
# forbeswomen                                  1.24                4.93
# travel                                       4.00                4.60
# markets                                      2.40                4.24
# hollywood & entertainment                    3.57                4.10
# personal finance                            11.41                3.87
# investing                                    1.89                3.79
# entrepreneurs                                0.92                3.68
# retail                                       0.57                3.27
# cmo network                                  0.19                3.22
# consumer tech                               10.62                2.77
# sportsmoney                                  2.43                2.42
# healthcare                                   5.93                2.09
# enterprise tech                              0.40                2.04
# taxes                                        0.85                2.00
# transportation                               0.48                1.85
# food & drink                                 0.36                1.78
#
# subscription_status        non_subscriber_rank  subscriber_rank
# GA_primarySection
# careers                                     14                1
# leadership strategy                         18                2
# games                                        1                3
# crypto & blockchain                          4                4
# forbeswomen                                 17                5
# travel                                       8                6
# markets                                     11                7
# hollywood & entertainment                    9                8
# personal finance                             2                9
# investing                                   13               10
# entrepreneurs                               22               11
# retail                                      26               12
# cmo network                                 37               13
# consumer tech                                3               14
# sportsmoney                                 10               15
# healthcare                                   6               16
# enterprise tech                             31               17
# taxes                                       24               18
# transportation                              29               19
# food & drink                                32               20

# %% [markdown]
# ### Avg. TOP in various content categories
# * Content categories = IAB Tier 1, Tier 2

# %%
t1 = cat.pivot_table(index=['GA_fullVisitorId'], 
                     columns='tier1',
                     values=['timeOnPage', 'GA_pageViews'], 
                     aggfunc='sum', 
                     fill_value=0).reset_index()
# set aside fvids
fvids = list(t1.GA_fullVisitorId)

# calc avg. top
t1_top = t1["timeOnPage"]/t1["GA_pageViews"]
t1_top = t1_top.fillna(0)

t1_top["GA_fullVisitorId"] = fvids
t1_top = pd.merge(t1_top, target_class, how="left", on="GA_fullVisitorId")

# %% [markdown]
# * Average time on page - Tier 1
#
#     * Subs spending more time on
#         * Busi & Fin, Personal Fin, News & Politics, Careers
#     * Non-subs spending more time on
#         * Video Gaming

# %%
top_eda(t1_top).rename(columns={'non_subscriber': 'non_subscriber avg. top', 'subscriber': 'subscriber avg. top'})
# Out:
# subscription_status       non_subscriber avg. top  subscriber avg. top  \
# Business and Finance                        15.38               124.70
# Personal Finance                            14.24                78.29
# Technology & Computing                      14.21                66.85
# News and Politics                            7.00                60.41
# Medical Health                               9.88                60.07
# Careers                                      1.61                35.53
# Travel                                       3.64                33.46
# Style & Fashion                              1.88                27.92
# Sports                                       2.94                26.50
# Shopping                                     1.40                26.38
# Automotive                                   3.13                25.01
# Education                                    0.79                24.96
# Food & Drink                                 1.12                24.25
# Real Estate                                  1.27                23.31
# Events and Attractions                       0.79                21.33
# Science                                      3.16                20.62
# Television                                   3.54                19.36
# Healthy Living                               1.18                17.23
# Home & Garden                                2.34                15.79
# Video Gaming                                 6.19                13.68
# Family and Relationships                     0.44                13.07
# Movies                                       1.73                12.71
# Music and Audio                              1.08                11.86
# Pop Culture                                  0.72                10.75
# Hobbies & Interests                          0.65                 7.96
# Books and Literature                         0.24                 6.35
# Fine Art                                     0.40                 4.69
# Pets                                         0.36                 4.00
# Content Channel                              0.13                 2.73
# Religion & Spirituality                      0.04                 1.42
#
# subscription_status       non_subscriber_rank  subscriber_rank
# Business and Finance                        1                1
# Personal Finance                            2                2
# Technology & Computing                      3                3
# News and Politics                           5                4
# Medical Health                              4                5
# Careers                                    15                6
# Travel                                      7                7
# Style & Fashion                            13                8
# Sports                                     11                9
# Shopping                                   16               10
# Automotive                                 10               11
# Education                                  21               12
# Food & Drink                               19               13
# Real Estate                                17               14
# Events and Attractions                     22               15
# Science                                     9               16
# Television                                  8               17
# Healthy Living                             18               18
# Home & Garden                              12               19
# Video Gaming                                6               20
# Family and Relationships                   25               21
# Movies                                     14               22
# Music and Audio                            20               23
# Pop Culture                                23               24
# Hobbies & Interests                        24               25
# Books and Literature                       28               26
# Fine Art                                   26               27
# Pets                                       27               28
# Content Channel                            29               29
# Religion & Spirituality                    30               30

# %% [markdown]
# * Average time on page - Tier 2
#
#     * Subs spending more time on
#         * Business, Industries
#     * Non-subs spending more time on
#         * Computing, Economy, Personal Debt

# %%
t2 = cat.pivot_table(index=['GA_fullVisitorId'], 
                     columns='tier2',
                     values=['timeOnPage', 'GA_pageViews'], 
                     aggfunc='sum', 
                     fill_value=0).reset_index()
# set aside fvids
fvids = list(t2.GA_fullVisitorId)

# calc avg. top
t2_top = t2["timeOnPage"]/t2["GA_pageViews"]
t2_top = t2_top.fillna(0)

t2_top["GA_fullVisitorId"] = fvids
t2_top = pd.merge(t2_top, target_class, how="left", on="GA_fullVisitorId")

top_eda(t2_top).rename(columns={'non_subscriber': 'non_subscriber avg. top', 'subscriber': 'subscriber avg. top'}).head(15)
# Out:
# subscription_status      non_subscriber avg. top  subscriber avg. top  \
# Business                                    7.72               100.84
# Industries                                  4.24                75.79
# Computing                                   9.70                54.85
# Economy                                     5.69                54.83
# Personal Investing                          4.19                52.46
# Diseases and Conditions                     4.90                48.25
# Politics                                    3.54                37.99
# Vaccines                                    3.65                24.47
# Travel Type                                 1.74                23.52
# Consumer Electronics                        6.38                22.75
# Law                                         2.00                22.21
# Personal Debt                               6.80                21.74
# Job Search                                  0.86                19.48
# Remote Working                              0.34                17.01
# Auto Type                                   1.09                16.75
#
# subscription_status      non_subscriber_rank  subscriber_rank
# Business                                   2                1
# Industries                                 7                2
# Computing                                  1                3
# Economy                                    5                4
# Personal Investing                         8                5
# Diseases and Conditions                    6                6
# Politics                                  11                7
# Vaccines                                  10                8
# Travel Type                               15                9
# Consumer Electronics                       4               10
# Law                                       14               11
# Personal Debt                              3               12
# Job Search                                27               13
# Remote Working                            42               14
# Auto Type                                 23               15

# %% [markdown]
# ### Avg. article views in each month

# %%
user_per_mon = pd.DataFrame(content.groupby(['GA_fullVisitorId', 'subscription_status', 'mon_year']).GA_pageViews.sum()).reset_index().rename(columns=
                                                                                                                                                   {'GA_pageViews':'total_article_views'})
user_per_mon
# Out:
#              GA_fullVisitorId subscription_status mon_year  \
# 0         1000000948120006249      non_subscriber  2021-10
# 1        10000078774942201969      non_subscriber  2021-08
# 2        10000078774942201969      non_subscriber  2021-09
# 3        10000078774942201969      non_subscriber  2021-10
# 4        10000093321793562421      non_subscriber  2021-10
# ...                       ...                 ...      ...
# 1018327   9999428991944010204          subscriber  2021-09
# 1018328   9999453033634739955      non_subscriber  2021-10
# 1018329   9999617506304669367      non_subscriber  2021-10
# 1018330   9999621821965685242      non_subscriber  2021-10
# 1018331   9999737912842746322      non_subscriber  2021-10
#
#          total_article_views
# 0                          1
# 1                          1
# 2                          2
# 3                          2
# 4                          1
# ...                      ...
# 1018327                    3
# 1018328                    1
# 1018329                    1
# 1018330                    1
# 1018331                    1
#
# [1018332 rows x 4 columns]

# %%
per_mon =  pd.DataFrame(user_per_mon.groupby(['GA_fullVisitorId', 'subscription_status']).total_article_views.mean()).reset_index() 

per_mon.GA_cmsNaturalId = per_mon.total_article_views.round() 
per_mon
# Out:
#             GA_fullVisitorId subscription_status  total_article_views
# 0        1000000948120006249      non_subscriber                 1.00
# 1       10000078774942201969      non_subscriber                 1.67
# 2       10000093321793562421      non_subscriber                 1.00
# 3       10000127776222822445      non_subscriber                 1.00
# 4       10000206856643135086      non_subscriber                 1.25
# ...                      ...                 ...                  ...
# 501296   9999428991944010204          subscriber                 3.50
# 501297   9999453033634739955      non_subscriber                 1.00
# 501298   9999617506304669367      non_subscriber                 1.00
# 501299   9999621821965685242      non_subscriber                 1.00
# 501300   9999737912842746322      non_subscriber                 1.00
#
# [501301 rows x 3 columns]

# %% [markdown]
# * Avg(actual articles per month)
#     * Subs on whole have been reading more articles in a month than non-subs

# %%
per_mon.groupby('subscription_status').total_article_views.describe().T
# Out:
# subscription_status  non_subscriber  subscriber
# count                     409988.00    91313.00
# mean                           1.37       13.46
# std                            0.82       25.88
# min                            1.00        1.00
# 25%                            1.00        4.33
# 50%                            1.00        8.00
# 75%                            1.50       14.80
# max                           89.67     2849.55

# %% [markdown]
# ### Bounce rate

# %%
print(session.shape)
print(len(session.GA_fullVisitorId.unique()))
# Out:
# (3296972, 5)
# 509084

# %%
def b_rate(g):
    '''for each fvid: calculate percentage of sessions comprising only 1PV'''
    
    # count sessions w/ pv = 1
    sessions_w_1pv = g[g['unique_pageViews']==1].shape[0]
    
    # count total sessions
    total_sessions = g.shape[0]
    
    # calculate ratio
    return (sessions_w_1pv)/total_sessions

# %%
br = pd.DataFrame(session.groupby('GA_fullVisitorId').apply(lambda x: b_rate(x))).reset_index().rename(columns={0:'bounce_rate'}) # takes 3mins 10.07

# %%
br = pd.merge(br, target_class, how="left", on="GA_fullVisitorId")
br
# Out:
#             GA_fullVisitorId  bounce_rate subscription_status
# 0        1000000948120006249         1.00      non_subscriber
# 1       10000078774942201969         0.67      non_subscriber
# 2       10000093321793562421         1.00      non_subscriber
# 3       10000127776222822445         1.00      non_subscriber
# 4       10000206856643135086         1.00      non_subscriber
# ...                      ...          ...                 ...
# 509079   9999428991944010204         0.81          subscriber
# 509080   9999453033634739955         1.00      non_subscriber
# 509081   9999617506304669367         1.00      non_subscriber
# 509082   9999621821965685242         1.00      non_subscriber
# 509083   9999737912842746322         1.00      non_subscriber
#
# [509084 rows x 3 columns]

# %% [markdown]
# * Non-subs have higher bounce rate than subs

# %%
br.groupby('subscription_status').bounce_rate.describe().T
# Out:
# subscription_status  non_subscriber  subscriber
# count                     409988.00    99096.00
# mean                           0.98        0.55
# std                            0.10        0.30
# min                            0.00        0.00
# 25%                            1.00        0.37
# 50%                            1.00        0.60
# 75%                            1.00        0.77
# max                            1.00        1.00

# %% [markdown]
# ### Content views rate

# %%
natid_page_map = df[['GA_pagePath', 'GA_cmsNaturalId', 'publish_date']].sort_values('publish_date', ascending=False).drop_duplicates('GA_pagePath')

# %%
page = pd.merge(page, 
                natid_page_map, 
                how="left", 
                on="GA_pagePath")
page
# Out:
#              GA_fullVisitorId  GA_visitStartTime  \
# 0         1000000948120006249         1635456756
# 1        10000078774942201969         1629090740
# 2        10000078774942201969         1632746707
# 3        10000078774942201969         1632746707
# 4        10000078774942201969         1634413951
# ...                       ...                ...
# 5400712   9999428991944010204         1631618760
# 5400713   9999453033634739955         1633461706
# 5400714   9999617506304669367         1633783846
# 5400715   9999621821965685242         1633456653
# 5400716   9999737912842746322         1635299022
#
#                                                GA_pagePath  GA_pageViews  \
# 0        /sites/abigailabesamis/2021/10/22/this-lazy-pe...             1
# 1        /sites/williamhaseltine/2021/08/10/it-is-time-...             1
# 2        /sites/deloitte/2021/08/03/to-mitigate-risk-in...             1
# 3        /sites/ellevate/2013/10/18/what-to-expect-duri...             1
# 4        /sites/forbes-personal-shopper/2021/09/21/dagn...             1
# ...                                                    ...           ...
# 5400712  /sites/leahcampbell/2021/06/26/moderna-or-pfiz...             1
# 5400713  /sites/japan/2020/10/30/powered-by-entrepreneu...             1
# 5400714  /sites/zackfriedman/2021/10/09/why-student-loa...             1
# 5400715  /sites/paultassi/2021/10/01/cdpr-warns-investo...             1
# 5400716  /sites/forbes-personal-shopper/2021/10/10/best...             1
#
#          GA_scrollDepth  timeOnPage  \
# 0                  0.25      521.00
# 1                  0.25       15.00
# 2                   nan       31.00
# 3                  1.00      152.00
# 4                  0.75       30.00
# ...                 ...         ...
# 5400712            0.25       22.00
# 5400713            0.75       97.00
# 5400714            0.50       52.00
# 5400715            0.50       12.00
# 5400716            0.00       23.00
#
#                                            GA_cmsNaturalId        publish_date
# 0        blogandpostid/blog/post/6190-6172f0890a6329000... 2021-10-22 13:27:54
# 1        blogandpostid/blog/post/5566-61126dd6dd43d6000... 2021-08-10 08:55:52
# 2        blogandpostid/blog/post/3585-610964dfb4025a000... 2021-08-03 12:30:19
# 3                        blogandpostid/blog/post/1386-2670 2013-10-18 11:26:00
# 4        blogandpostid/blog/post/4983-6148df6746a14f000... 2021-09-21 13:14:04
# ...                                                    ...                 ...
# 5400712  blogandpostid/blog/post/50736-60d79acc0157d100... 2021-06-26 17:26:44
# 5400713  blogandpostid/blog/post/5436-5f9c3ef5d05362000... 2020-10-30 12:41:37
# 5400714  blogandpostid/blog/post/4804-615e63fbd2392d000... 2021-10-09 08:30:00
# 5400715  blogandpostid/blog/post/1174-615706f3accd12000... 2021-10-01 09:06:06
# 5400716  blogandpostid/blog/post/4983-60086702e0ca9e000... 2021-10-10 10:01:56
#
# [5400717 rows x 8 columns]

# %%
def c_views_rate(g):
    '''for each fvid: calculate percentage PVs that are actually views on content pages; vs non-content pages such as the home page, channel/section landing pages, author pages, etc.'''
    
    # sum pvs on actual content for user
    content_sum_pv = g[g.GA_cmsNaturalId.str.contains("blogandpostid|blogandslideid|galleryid|video")].GA_pageViews.sum()
    
    # sum all pvs for user
    total_pv = g.GA_pageViews.sum()
    
    # calculate ratio
    return (content_sum_pv)/total_pv

# %%
cvr = pd.DataFrame(page.groupby('GA_fullVisitorId').apply(lambda x: c_views_rate(x))).reset_index().rename(columns={0:'content_views_rate'}) # takes 5mins

# %%
cvr = pd.merge(cvr, target_class, how="left", on="GA_fullVisitorId")
cvr

# %% [markdown]
# * Non-subs have higher content views rate i.e., they mostly come for just the content. Subs roam around on the website

# %%
cvr.groupby('subscription_status').content_views_rate.describe().T
# Out:
# subscription_status  non_subscriber  subscriber
# count                     409988.00    99096.00
# mean                           0.99        0.70
# std                            0.05        0.29
# min                            0.01        0.00
# 25%                            1.00        0.55
# 50%                            1.00        0.78
# 75%                            1.00        0.94
# max                            1.00        1.00

# %%
# both these metrics (bounce_rate and content_views_rate) have slight positive correlation

pd.merge(cvr, br, how="inner", on = "GA_fullVisitorId").corr()
# Out:
#                     content_views_rate  bounce_rate
# content_views_rate                1.00         0.62
# bounce_rate                       0.62         1.00
